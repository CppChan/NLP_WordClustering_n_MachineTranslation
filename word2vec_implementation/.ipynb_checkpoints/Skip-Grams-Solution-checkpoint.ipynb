# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
#
# First up, importing packages.

# %%
# !wget https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/utils.py
# Out:
# --2018-08-11 11:23:51--  https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133, 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2194 (2.1K) [text/plain]
# Saving to: 'utils.py'
#
# utils.py            100%[===================>]   2.14K  --.-KB/s    in 0s
#
# 2018-08-11 11:23:52 (12.8 MB/s) - 'utils.py' saved [2194/2194]

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

if not isfile(dataset_filename):
    urlretrieve(
          'http://mattmahoney.net/dc/text8.zip',
          dataset_filename)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
print(text)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here create dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]#every word's position in the input vector

# %%
print (int_to_vocab)
# Out:
# {0: 'the', 1: 'of', 2: 'and', 3: 'one', 4: 'in', 5: 'a', 6: 'to', 7: 'zero', 8: 'nine', 9: 'two', 10: 'is', 11: 'as', 12: 'eight', 13: 'for', 14: 's', 15: 'five', 16: 'three', 17: 'was', 18: 'by', 19: 'that', 20: 'four', 21: 'six', 22: 'seven', 23: 'with', 24: 'on', 25: 'are', 26: 'it', 27: 'from', 28: 'or', 29: 'his', 30: 'an', 31: 'be', 32: 'this', 33: 'which', 34: 'at', 35: 'he', 36: 'also', 37: 'not', 38: 'have', 39: 'were', 40: 'has', 41: 'but', 42: 'other', 43: 'their', 44: 'its', 45: 'first', 46: 'they', 47: 'some', 48: 'had', 49: 'all', 50: 'more', 51: 'most', 52: 'can', 53: 'been', 54: 'such', 55: 'many', 56: 'who', 57: 'new', 58: 'used', 59: 'there', 60: 'after', 61: 'when', 62: 'into', 63: 'american', 64: 'time', 65: 'these', 66: 'only', 67: 'see', 68: 'may', 69: 'than', 70: 'world', 71: 'i', 72: 'b', 73: 'would', 74: 'd', 75: 'no', 76: 'however', 77: 'between', 78: 'about', 79: 'over', 80: 'years', 81: 'states', 82: 'people', 83: 'war', 84: 'during', 85: 'united', 86: 'known', 87: 'if', 88: 'called', 89: 'use', 90: 'th', 91: 'system', 92: 'often', 93: 'state', 94: 'so', 95: 'history', 96: 'will', 97: 'up', 98: 'while', 99: 'where', 100: 'city', 101: 'being', 102: 'english', 103: 'then', 104: 'any', 105: 'both', 106: 'under', 107: 'out', 108: 'made', 109: 'well', 110: 'her', 111: 'e', 112: 'number', 113: 'government', 114: 'them', 115: 'm', 116: 'later', 117: 'since', 118: 'him', 119: 'part', 120: 'name', 121: 'c', 122: 'century', 123: 'through', 124: 'because', 125: 'x', 126: 'university', 127: 'early', 128: 'life', 129: 'british', 130: 'year', 131: 'like', 132: 'same', 133: 'including', 134: 'became', 135: 'example', 136: 'day', 137: 'each', 138: 'even', 139: 'work', 140: 'language', 141: 'although', 142: 'several', 143: 'form', 144: 'john', 145: 'u', 146: 'national', 147: 'very', 148: 'much', 149: 'g', 150: 'french', 151: 'before', 152: 'general', 153: 'what', 154: 't', 155: 'against', 156: 'n', 157: 'high', 158: 'links', 159: 'could', 160: 'based', 161: 'those', 162: 'now', 163: 'second', 164: 'de', 165: 'music', 166: 'another', 167: 'large', 168: 'she', 169: 'f', 170: 'external', 171: 'german', 172: 'different', 173: 'modern', 174: 'great', 175: 'do', 176: 'common', 177: 'set', 178: 'list', 179: 'south', 180: 'series', 181: 'major', 182: 'game', 183: 'power', 184: 'long', 185: 'country', 186: 'king', 187: 'law', 188: 'group', 189: 'film', 190: 'still', 191: 'until', 192: 'north', 193: 'international', 194: 'term', 195: 'we', 196: 'end', 197: 'book', 198: 'found', 199: 'own', 200: 'political', 201: 'party', 202: 'order', 203: 'usually', 204: 'president', 205: 'church', 206: 'you', 207: 'death', 208: 'theory', 209: 'area', 210: 'around', 211: 'include', 212: 'god', 213: 'ii', 214: 'way', 215: 'did', 216: 'military', 217: 'population', 218: 'using', 219: 'though', 220: 'small', 221: 'following', 222: 'within', 223: 'non', 224: 'human', 225: 'left', 226: 'main', 227: 'among', 228: 'point', 229: 'r', 230: 'due', 231: 'p', 232: 'considered', 233: 'public', 234: 'popular', 235: 'computer', 236: 'west', 237: 'family', 238: 'east', 239: 'information', 240: 'important', 241: 'european', 242: 'man', 243: 'sometimes', 244: 'right', 245: 'old', 246: 'free', 247: 'word', 248: 'without', 249: 'last', 250: 'us', 251: 'members', 252: 'given', 253: 'times', 254: 'roman', 255: 'make', 256: 'h', 257: 'age', 258: 'place', 259: 'l', 260: 'thus', 261: 'science', 262: 'case', 263: 'become', 264: 'systems', 265: 'union', 266: 'born', 267: 'york', 268: 'line', 269: 'countries', 270: 'does', 271: 'isbn', 272: 'st', 273: 'control', 274: 'various', 275: 'others', 276: 'house', 277: 'article', 278: 'island', 279: 'should', 280: 'led', 281: 'back', 282: 'period', 283: 'player', 284: 'europe', 285: 'languages', 286: 'central', 287: 'water', 288: 'few', 289: 'western', 290: 'home', 291: 'began', 292: 'generally', 293: 'less', 294: 'k', 295: 'similar', 296: 'written', 297: 'original', 298: 'best', 299: 'must', 300: 'according', 301: 'school', 3 ...

# %%
int_words
# Out:
# [5233,
#  3080,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10571,
#  133,
#  0,
#  27349,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15067,
#  58112,
#  1,
#  0,
#  150,
#  854,
#  3580,
#  0,
#  194,
#  10,
#  190,
#  58,
#  4,
#  5,
#  10712,
#  214,
#  6,
#  1324,
#  104,
#  454,
#  19,
#  58,
#  2731,
#  362,
#  6,
#  3672,
#  0,
#  708,
#  1,
#  371,
#  26,
#  40,
#  36,
#  53,
#  539,
#  97,
#  11,
#  5,
#  1423,
#  2757,
#  18,
#  567,
#  686,
#  7088,
#  0,
#  247,
#  5233,
#  10,
#  1052,
#  27,
#  0,
#  320,
#  248,
#  44611,
#  2877,
#  792,
#  186,
#  5233,
#  11,
#  5,
#  200,
#  602,
#  10,
#  0,
#  1134,
#  19,
#  2621,
#  25,
#  8983,
#  2,
#  279,
#  31,
#  4147,
#  141,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  153,
#  32,
#  362,
#  5233,
#  36,
#  1137,
#  6,
#  447,
#  344,
#  1818,
#  19,
#  4860,
#  0,
#  6753,
#  1,
#  7573,
#  1774,
#  566,
#  0,
#  93,
#  0,
#  247,
#  11064,
#  11,
#  51,
#  7088,
#  89,
#  26,
#  270,
#  37,
#  5948,
#  4861,
#  20299,
#  28,
#  53721,
#  41,
#  317,
#  5,
#  25636,
#  527,
#  7573,
#  371,
#  4,
#  258,
#  1,
#  153,
#  25,
#  1206,
#  11,
#  7573,
#  200,
#  1576,
#  2,
#  15200,
#  332,
#  1774,
#  7088,
#  4860,
#  344,
#  764,
#  160,
#  406,
#  5690,
#  755,
#  1,
#  4105,
#  1131,
#  4331,
#  1536,
#  2,
#  567,
#  8117,
#  98,
#  5233,
#  10,
#  51,
#  1407,
#  686,
#  18,
#  153,
#  26,
#  10,
#  155,
#  7088,
#  36,
#  2033,
#  1423,
#  8174,
#  1,
#  153,
#  46,
#  693,
#  6,
#  31,
#  5,
#  4148,
#  246,
#  371,
#  76,
#  948,
#  78,
#  310,
#  30,
#  4778,
#  371,
#  507,
#  139,
#  2312,
#  3553,
#  364,
#  23,
#  1821,
#  6,
#  1902,
#  59,
#  10,
#  36,
#  8399,
#  78,
#  310,
#  5,
#  246,
#  371,
#  507,
#  31,
#  753,
#  78,
#  1732,
#  2,
#  8040,
#  24172,
#  2,
#  275,
#  1693,
#  19,
#  151,
#  1032,
#  95,
#  224,
#  371,
#  17,
#  1813,
#  24,
#  4778,
#  1556,
#  51,
#  8118,
#  1465,
#  24172,
#  2,
#  12743,
#  4,
#  6130,
#  19,
#  4187,
#  21148,
#  2427,
#  39,
#  16455,
#  2,
#  7239,
#  861,
#  1,
#  1193,
#  10207,
#  2514,
#  28,
#  15068,
#  187,
#  2,
#  48,
#  1123,
#  912,
#  6,
#  1049,
#  467,
#  12297,
#  7088,
#  133,
#  0,
#  0,
#  11064,
#  3055,
#  2,
#  12060,
#  734,
#  4778,
#  6598,
#  4,
#  14622,
#  27,
#  450,
#  485,
#  24172,
#  198,
#  295,
#  948,
#  4,
#  20027,
#  20300,
#  1,
#  53722,
#  300,
#  6,
#  24172,
#  20300,
#  16456,
#  0,
#  30106,
#  1,
#  0,
#  93,
#  44,
#  3832,
#  2,
#  53723,
#  2,
#  3807,
#  0,
#  3412,
#  1,
#  0,
#  1776,
#  187,
#  1,
#  0,
#  625,
#  0,
#  13141,
#  1,
#  3,
#  21,
#  90,
#  122,
#  284,
#  25,
#  243,
#  232,
#  6,
#  31,
#  436,
#  26184,
#  1,
#  173,
#  5233,
#  7699,
#  2534,
#  4,
#  29,
#  95,
#  1,
#  289,
#  602,
#  4308,
#  19,
#  0,
#  13141,
#  16456,
#  49,
#  187,
#  117,
#  46,
#  359,
#  19,
#  0,
#  384,
#  242,
#  96,
#  31,
#  5234,
#  34,
#  331,
#  2723,
#  18,
#  0,
#  838,
#  1376,
#  27,
#  32,
#  8761,
#  46,
#  6470,
#  34,
#  3243,
#  0,
#  27349,
#  28,
#  551,
#  42432,
#  39,
#  30,
#  127,
#  53724,
#  435,
#  84,
#  0,
#  64,
#  1,
#  0,
#  102,
#  462,
#  83,
#  2,
#  25,
#  232,
#  18,
#  47,
#  11,
#  26184,
#  1,
#  173,
#  5233,
#  4,
#  0,
#  173,
#  839,
#  0,
#  45,
#  6,
#  89,
#  0,
#  194,
#  6,
#  1014,
#  1043,
#  42,
#  69,
#  4861,
#  17,
#  936,
#  14920,
#  4571,
#  164,
#  4,
#  29,
#  40561,
#  11815,
#  22892,
#  259,
#  1225,
#  58113,
#  3,
#  22,
#  7,
#  16,
#  99,
#  35,
#  628,
#  0,
#  2662,
#  63,
#  371,
#  33,
#  48,
#  75,
#  93,
#  687,
#  14777,
#  4044,
#  28,
#  817,
#  917,
#  11,
#  101,
#  4,
#  11064,
#  2534,
#  362,
#  5,
#  6054,
#  2,
#  662,
#  4,
#  0,
#  63,
#  701,
#  435,
#  40,
#  4218,
#  1289,
#  19,
#  35,
#  10,
#  30,
#  4778,
#  2,
#  94,
#  25,
#  49,
#  29,
#  5212,
#  4,
#  3,
#  22,
#  8,
#  16,
#  4,
#  0,
#  5348,
#  1,
#  0,
#  150,
#  854,
#  467,
#  12297,
#  334,
#  30,
#  17194,
#  2434,
#  200,
#  1293,
#  141,
#  12297,
#  215,
#  37,
#  89,
#  0,
#  247,
#  5233,
#  55,
#  116,
#  7088,
#  38,
#  1206,
#  32,
#  197,
#  11,
#  0,
#  45,
#  181,
#  4778,
#  529,
#  2,
#  12297,
#  11,
#  0,
#  1834,
#  1,
#  1912,
#  5233,
#  41,
#  34,
#  32,
#  228,
#  75,
#  4778,
#  435,
#  733,
#  2399,
#  2,
#  0,
#  194,
#  17,
#  86,
#  1073,
#  11,
#  30,
#  14022,
#  30107,
#  18,
#  0,
#  12061,
#  58114,
#  34,
#  50,
#  2419,
#  616,
#  4,
#  0,
#  150,
#  854,
#  0,
#  45,
#  567,
#  8716,
#  4778,
#  2935,
#  1033,
#  14497,
#  26,
#  10,
#  636,
#  359,
#  19,
#  26,
#  5385,
#  154,
#  191,
#  2935,
#  1033,
#  14497,
#  334,
#  153,
#  10,
#  917,
#  4,
#  3,
#  12,
#  20,
#  7,
#  19,
#  0,
#  194,
#  4778,
#  17,
#  989,
#  11,
#  5,
#  567,
#  1606,
#  26,
#  10,
#  13,
#  32,
#  890,
#  19,
#  47,
#  848,
#  14497,
#  11,
#  0,
#  1834,
#  1,
#  173,
#  4778,
#  208,
#  4,
#  153,
#  10,
#  917,
#  14497,
#  5463,
#  23,
#  0,
#  419,
#  12953,
#  917,
#  10,
#  6878,
#  4,
#  32,
#  139,
#  35,
#  1346,
#  0,
#  2878,
#  1,
#  15068,
#  917,
#  154,
#  99,
#  3465,
#  38,
#  652,
#  445,
#  6,
#  89,
#  2,
#  3133,
#  43,
#  917,
#  11,
#  46,
#  3591,
#  54,
#  11,
#  15347,
#  1555,
#  13,
#  2965,
#  4,
#  44,
#  258,
#  14497,
#  1164,
#  153,
#  35,
#  88,
#  3221,
#  1131,
#  52,
#  38,
#  751,
#  445,
#  6,
#  89,
#  1049,
#  522,
#  2,
#  1791,
#  4,
#  5805,
#  23,
#  1556,
#  1,
#  5128,
#  2,
#  1293,
#  14497,
#  14,
#  2654,
#  1,
#  11064,
#  33,
#  35,
#  88,
#  29372,
#  966,
#  30,
#  1334,
#  518,
#  99,
#  1131,
#  2,
#  308,
#  159,
#  512,
#  0,
#  805,
#  1,
#  43,
#  1258,
#  218,
#  1258,
#  1037,
#  33,
#  1391,
#  0,
#  908,
#  1,
#  741,
#  64,
#  966,
#  4,
#  442,
#  32,
#  73,
#  2913,
#  19,
#  75,
#  3,
#  73,
#  2965,
#  27,
#  0,
#  1258,
#  1,
#  275,
#  1555,
#  159,
#  4319,
#  2518,
#  498,
#  4,
#  727,
#  10638,
#  18741,
#  30,
#  762,
#  246,
#  986,
#  73,
#  31,
#  177,
#  97,
#  6,
#  740,
#  3272,
#  23,
#  912,
#  6,
#  0,
#  362,
#  1,
#  442,
#  14497,
#  14,
#  948,
#  39,
#  2025,
#  222,
#  150,
#  741,
#  476,
#  1818,
#  2,
#  29,
#  2985,
#  39,
#  1021,
#  4,
#  0,
#  854,
#  1,
#  3,
#  12,
#  20,
#  12,
#  4,
#  302,
#  14497,
#  14,
#  602,
#  1,
#  917,
#  10,
#  647,
#  26,
#  17,
#  347,
#  4,
#  5,
#  112,
#  1,
#  311,
#  79,
#  29,
#  3567,
#  2,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  47,
#  1,
#  29,
#  948,
#  13,
#  50,
#  2158,
#  1589,
#  67,
#  621,
#  2749,
#  26185,
#  14,
#  15643,
#  4,
#  29,
#  0,
#  10464,
#  2,
#  44,
#  199,
#  26185,
#  1460,
#  19,
#  51,
#  636,
#  1045,
#  344,
#  1774,
#  133,
#  0,
#  2581,
#  1,
#  93,
#  917,
#  11,
#  5,
#  244,
#  389,
#  445,
#  4,
#  152,
#  2,
#  0,
#  147,
#  2581,
#  1,
#  371,
#  39,
#  4579,
#  20847,
#  28,
#  9216,
#  4,
#  0,
#  940,
#  1974,
#  1,
#  371,
#  19,
#  0,
#  1131,
#  25,
#  44,
#  1728,
#  35,
#  5213,
#  15643,
#  2,
#  5,
#  143,
#  1,
#  4,
#  33,
#  1131,
#  73,
#  9711,
#  4,
#  5825,
#  1,
#  50095,
#  66,
#  61,
#  26,
#  17,
#  4,
#  43,
#  567,
#  762,
#  6,
#  175,
#  94,
#  13,
#  118,
#  917,
#  684,
#  1145,
#  78,
#  123,
#  507,
#  13042,
#  5567,
#  310,
#  6,
#  369,
#  6,
#  4106,
#  0,
#  1797,
#  6,
#  118,
#  5464,
#  917,
#  2,
#  153,
#  71,
#  38,
#  4,
#  608,
#  183,
#  19,
#  10,
#  608,
#  199,
#  94,
#  184,
#  11,
#  71,
#  6187,
#  9033,
#  11,
#  7183,
#  71,
#  1225,
#  0,
#  33800,
#  1,
#  0,
#  1797,
#  26185,
#  363,
#  88,
#  391,
#  30,
#  4778,
#  35,
#  1045,
#  66,
#  0,
#  2757,
#  42433,
#  2068,
#  29,
#  948,
#  39,
#  2025,
#  24,
#  55,
#  9929,
#  7088,
#  141,
#  4186,
#  1,
#  29,
#  501,
#  25,
#  3235,
#  63,
#  10270,
#  5233,
#  3244,
#  9606,
#  4,
#  3,
#  ...]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
len(int_words)
# Out:
# 16680599

# %%
len(train_words)
# Out:
# 4628128

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    R,res,i = np.random.randint(1, window_size+1),[words[idx]],1
    while i<=R:
        if idx-i>=0:words.insert(0, words[idx-i])
        if index+i<len(words):words.append(words[index+i])
        i+=1
    return list(set(res))

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):#words = train_words
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    print (len(words))
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]# is the position of certain word
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)#batch_y like [2,4,10,3], each is the 2 nearest word
            x.extend([batch_x]*len(batch_y))#[batch_x]*len(batch_y) like [5,5,5,5], 5 is the input word 
        yield x, y# x's size is 1000*(2*window_size)

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
#  Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))#4628128*200 matrix
    embed = tf.nn.embedding_lookup(embedding, inputs)#1*200 vector for every word

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-35-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %%
batches = get_batches(train_words, 1000, 10)
next(batches)
# for i in batches:
#     print(i)
# Out:
# 4628000
# ([5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   476,
#   476,
#   476,
#   10571,
#   10571,
#   10571,
#   10571,
#   10571,
#   10571,
#   10571,
#   27349,
#   27349,
#   27349,
#   27349,
#   27349,
#   27349,
#   27349,
#   27349,
#   27349,
#   27349,
#   27349,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   15067,
#   15067,
#   15067,
#   58112,
#   58112,
#   58112,
#   58112,
#   58112,
#   58112,
#   58112,
#   58112,
#   58112,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   854,
#   3580,
#   3580,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   2731,
#   2731,
#   2731,
#   2731,
#   2731,
#   2731,
#   2731,
#   2731,
#   2731,
#   2731,
#   2731,
#   371,
#   371,
#   371,
#   371,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   686,
#   686,
#   686,
#   686,
#   686,
#   686,
#   686,
#   686,
#   686,
#   686,
#   686,
#   686,
#   7088,
#   7088,
#   7088,
#   7088,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   602,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   2621,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   6437,
#   6437,
#   6437,
#   6437,
#   362,
#   362,
#   362,
#   362,
#   362,
#   362,
#   362,
#   362,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   447,
#   4860,
#   4860,
#   4860,
#   4860,
#   6753,
#   6753,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   1774,
#   1774,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   7088,
#   7088,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   89,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   20299,
#   20299,
#   20299,
#   20299,
#   20299,
#   20299,
#   20299,
#   20299,
#   53721,
#   53721,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   527,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   1206,
#   1206,
#   1206,
#   1206,
#   1206,
#   1206,
#   1206,
#   1206,
#   1206,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   200,
#   200,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   160,
#   755,
#   755,
#   1536,
#   1536,
#   1536,
#   1536,
#   1536,
#   1536,
#   1536,
#   1536,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   2033,
#   2033,
#   2033,
#   2033,
#   2033,
#   2033,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   310,
#   310,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   8399,
#   8399,
#   8399,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   78,
#   78,
#   78,
#   78,
#   78,
#   78,
#   78,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   24172,
#   24172,
#   1693,
#   1693,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   1465,
#   1465,
#   1465,
#   1465,
#   1465,
#   1465,
#   1465,
#   1465,
#   24172,
#   24172,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   12743,
#   6130,
#   6130,
#   6130,
#   6130,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   21148,
#   21148,
#   21148,
#   21148,
#   21148,
#   21148,
#   21148,
#   21148,
#   21148,
#   21148,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   2427,
#   16455,
#   16455,
#   16455,
#   16455,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   10207,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   15068,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   912,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   12297,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   133,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   4778,
#   4778,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   485,
#   485,
#   485,
#   485,
#   485,
#   485,
#   485,
#   485,
#   24172,
#   24172,
#   948,
#   948,
#   948,
#   948,
#   948,
#   948,
#   948,
#   948,
#   20027,
#   20027,
#   20027,
#   20027,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   53722,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   20300,
#   16456,
#   16456,
#   16456,
#   16456,
#   16456,
#   16456,
#   16456,
#   16456,
#   16456,
#   16456,
#   16456,
#   30106,
#   30106,
#   30106,
#   30106,
#   30106,
#   30106,
#   30106,
#   30106,
#   30106,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   93,
#   44,
#   44,
#   44,
#   44,
#   44,
#   44,
#   44,
#   44,
#   3832,
#   3832,
#   3832,
#   3832,
#   3832,
#   3832,
#   ...],
#  [58112,
#   10571,
#   27349,
#   854,
#   15067,
#   476,
#   5233,
#   10571,
#   27349,
#   58112,
#   3580,
#   5233,
#   27349,
#   854,
#   15067,
#   476,
#   58112,
#   2757,
#   10571,
#   2731,
#   3580,
#   5233,
#   371,
#   854,
#   10712,
#   15067,
#   476,
#   58112,
#   10571,
#   3580,
#   5233,
#   27349,
#   854,
#   10712,
#   15067,
#   476,
#   58112,
#   27349,
#   854,
#   10571,
#   2731,
#   3580,
#   371,
#   27349,
#   854,
#   10712,
#   15067,
#   476,
#   58112,
#   2757,
#   10571,
#   2731,
#   371,
#   27349,
#   854,
#   10712,
#   15067,
#   3580,
#   10712,
#   854,
#   58112,
#   2757,
#   2731,
#   371,
#   854,
#   567,
#   15067,
#   3580,
#   58112,
#   44611,
#   2757,
#   686,
#   7088,
#   371,
#   854,
#   567,
#   10712,
#   15067,
#   3580,
#   10712,
#   2731,
#   2757,
#   567,
#   58112,
#   44611,
#   2731,
#   686,
#   7088,
#   5233,
#   371,
#   854,
#   567,
#   10712,
#   602,
#   3580,
#   58112,
#   44611,
#   2757,
#   6437,
#   2731,
#   686,
#   7088,
#   5233,
#   371,
#   4147,
#   854,
#   8983,
#   10712,
#   602,
#   15067,
#   3580,
#   2621,
#   44611,
#   2757,
#   2731,
#   8983,
#   7088,
#   5233,
#   371,
#   567,
#   10712,
#   602,
#   3580,
#   2621,
#   5233,
#   44611,
#   686,
#   567,
#   58112,
#   4860,
#   2757,
#   6437,
#   362,
#   2731,
#   8983,
#   686,
#   7088,
#   5233,
#   371,
#   4147,
#   854,
#   567,
#   10712,
#   602,
#   3580,
#   2621,
#   447,
#   44611,
#   2757,
#   6437,
#   362,
#   8983,
#   686,
#   7088,
#   371,
#   4147,
#   567,
#   602,
#   2621,
#   44611,
#   2757,
#   6437,
#   362,
#   8983,
#   686,
#   7088,
#   5233,
#   371,
#   4147,
#   567,
#   2621,
#   447,
#   44611,
#   2757,
#   6437,
#   362,
#   8983,
#   686,
#   7088,
#   5233,
#   4147,
#   567,
#   602,
#   4860,
#   447,
#   6437,
#   362,
#   5233,
#   4147,
#   602,
#   2621,
#   6753,
#   44611,
#   6437,
#   362,
#   686,
#   7088,
#   5233,
#   7573,
#   8983,
#   602,
#   4860,
#   2621,
#   447,
#   5233,
#   362,
#   4147,
#   8983,
#   6753,
#   6437,
#   5233,
#   4147,
#   8983,
#   4860,
#   2621,
#   447,
#   6753,
#   6437,
#   362,
#   1774,
#   7088,
#   5233,
#   4147,
#   7573,
#   8983,
#   11064,
#   602,
#   4860,
#   2621,
#   447,
#   6753,
#   44611,
#   6437,
#   5948,
#   362,
#   20299,
#   53721,
#   1774,
#   7088,
#   5233,
#   4147,
#   7573,
#   8983,
#   11064,
#   89,
#   602,
#   4860,
#   2621,
#   5233,
#   6753,
#   7573,
#   447,
#   4860,
#   7573,
#   6753,
#   5948,
#   362,
#   1774,
#   7088,
#   5233,
#   11064,
#   89,
#   4860,
#   447,
#   11064,
#   7573,
#   6753,
#   1774,
#   7088,
#   7573,
#   89,
#   5948,
#   11064,
#   89,
#   6753,
#   25636,
#   5948,
#   200,
#   362,
#   20299,
#   1774,
#   527,
#   7088,
#   5233,
#   7573,
#   1206,
#   11064,
#   53721,
#   4860,
#   447,
#   25636,
#   20299,
#   53721,
#   1774,
#   527,
#   7088,
#   7573,
#   11064,
#   89,
#   25636,
#   53721,
#   527,
#   7088,
#   7573,
#   11064,
#   89,
#   5948,
#   20299,
#   25636,
#   200,
#   20299,
#   53721,
#   527,
#   7088,
#   7573,
#   1206,
#   89,
#   5948,
#   15200,
#   25636,
#   200,
#   1576,
#   20299,
#   53721,
#   1774,
#   7088,
#   7573,
#   1206,
#   11064,
#   89,
#   5948,
#   25636,
#   200,
#   527,
#   7573,
#   1206,
#   53721,
#   15200,
#   25636,
#   200,
#   1576,
#   20299,
#   1774,
#   527,
#   7573,
#   53721,
#   15200,
#   25636,
#   200,
#   1576,
#   1774,
#   527,
#   7573,
#   1206,
#   1576,
#   7573,
#   15200,
#   160,
#   1536,
#   25636,
#   200,
#   20299,
#   1774,
#   527,
#   7088,
#   5233,
#   755,
#   51,
#   7573,
#   1206,
#   8117,
#   53721,
#   5948,
#   160,
#   1536,
#   25636,
#   8174,
#   200,
#   1576,
#   20299,
#   1774,
#   527,
#   7088,
#   5233,
#   2033,
#   755,
#   51,
#   7573,
#   1206,
#   8117,
#   53721,
#   5948,
#   15200,
#   160,
#   1536,
#   200,
#   1576,
#   7088,
#   5233,
#   755,
#   7573,
#   1206,
#   8117,
#   15200,
#   160,
#   1536,
#   1576,
#   1774,
#   755,
#   15200,
#   1536,
#   8174,
#   200,
#   1576,
#   1774,
#   527,
#   7088,
#   5233,
#   2033,
#   755,
#   51,
#   7573,
#   1206,
#   8117,
#   310,
#   507,
#   160,
#   1536,
#   160,
#   1774,
#   7088,
#   5233,
#   2033,
#   755,
#   51,
#   8117,
#   1536,
#   160,
#   1774,
#   8174,
#   7088,
#   5233,
#   2033,
#   755,
#   51,
#   310,
#   160,
#   1536,
#   8174,
#   2033,
#   755,
#   51,
#   8117,
#   310,
#   1536,
#   160,
#   1774,
#   8174,
#   7088,
#   5233,
#   2033,
#   755,
#   8399,
#   8117,
#   310,
#   371,
#   507,
#   1821,
#   8174,
#   5233,
#   51,
#   8117,
#   310,
#   507,
#   8399,
#   2033,
#   5233,
#   51,
#   8117,
#   310,
#   507,
#   1821,
#   507,
#   8174,
#   8174,
#   8399,
#   2033,
#   51,
#   371,
#   310,
#   507,
#   1821,
#   1536,
#   8040,
#   4778,
#   24172,
#   8174,
#   8399,
#   78,
#   5233,
#   2033,
#   755,
#   51,
#   8117,
#   310,
#   371,
#   507,
#   1693,
#   371,
#   507,
#   1821,
#   1693,
#   8040,
#   4778,
#   24172,
#   8174,
#   8399,
#   78,
#   2033,
#   5233,
#   51,
#   371,
#   8117,
#   310,
#   8118,
#   1465,
#   507,
#   1821,
#   1693,
#   8040,
#   4778,
#   24172,
#   8174,
#   8399,
#   78,
#   5233,
#   2033,
#   51,
#   371,
#   310,
#   8118,
#   1465,
#   507,
#   1821,
#   1693,
#   8040,
#   24172,
#   8399,
#   371,
#   507,
#   1821,
#   1693,
#   12743,
#   4778,
#   24172,
#   8174,
#   8399,
#   78,
#   371,
#   310,
#   8118,
#   1465,
#   507,
#   1821,
#   8040,
#   1693,
#   371,
#   24172,
#   12743,
#   8040,
#   4778,
#   24172,
#   78,
#   6130,
#   371,
#   8118,
#   1465,
#   507,
#   1693,
#   1693,
#   12743,
#   8040,
#   16455,
#   4187,
#   24172,
#   78,
#   8399,
#   6130,
#   371,
#   2427,
#   8118,
#   1465,
#   507,
#   21148,
#   1821,
#   12743,
#   4778,
#   24172,
#   6130,
#   371,
#   1465,
#   1693,
#   12743,
#   4778,
#   24172,
#   6130,
#   371,
#   8118,
#   4187,
#   1693,
#   1465,
#   12743,
#   16455,
#   7239,
#   4778,
#   24172,
#   6130,
#   371,
#   2427,
#   8118,
#   1465,
#   4187,
#   21148,
#   1693,
#   21148,
#   4187,
#   24172,
#   12743,
#   15068,
#   12743,
#   8040,
#   16455,
#   4778,
#   7239,
#   24172,
#   12297,
#   912,
#   7088,
#   6130,
#   371,
#   2514,
#   8118,
#   1465,
#   2427,
#   21148,
#   1693,
#   10207,
#   12743,
#   16455,
#   7239,
#   24172,
#   6130,
#   2427,
#   2514,
#   1465,
#   4187,
#   10207,
#   15068,
#   12743,
#   16455,
#   7239,
#   12297,
#   24172,
#   912,
#   6130,
#   2514,
#   8118,
#   1465,
#   4187,
#   21148,
#   10207,
#   10207,
#   2427,
#   21148,
#   7239,
#   15068,
#   12743,
#   16455,
#   12297,
#   4187,
#   912,
#   7088,
#   6130,
#   2514,
#   2427,
#   21148,
#   10207,
#   15068,
#   133,
#   12743,
#   16455,
#   7239,
#   4187,
#   12297,
#   912,
#   7088,
#   6130,
#   2514,
#   11064,
#   2427,
#   21148,
#   15068,
#   133,
#   12060,
#   12743,
#   16455,
#   7239,
#   12297,
#   4778,
#   24172,
#   6598,
#   912,
#   7088,
#   6130,
#   2427,
#   11064,
#   1465,
#   4187,
#   21148,
#   14622,
#   10207,
#   133,
#   12060,
#   16455,
#   7239,
#   12297,
#   4187,
#   4778,
#   6598,
#   912,
#   7088,
#   6130,
#   2514,
#   11064,
#   2427,
#   21148,
#   10207,
#   15068,
#   133,
#   12060,
#   7239,
#   16455,
#   12297,
#   4187,
#   4778,
#   6598,
#   7088,
#   2514,
#   11064,
#   2427,
#   21148,
#   14622,
#   10207,
#   450,
#   15068,
#   133,
#   12060,
#   16455,
#   7239,
#   6598,
#   4187,
#   4778,
#   485,
#   24172,
#   912,
#   7088,
#   6130,
#   2514,
#   11064,
#   2427,
#   21148,
#   14622,
#   10207,
#   133,
#   12060,
#   7239,
#   6598,
#   12297,
#   4778,
#   912,
#   2514,
#   11064,
#   15068,
#   14622,
#   10207,
#   450,
#   12060,
#   6598,
#   7239,
#   16455,
#   12297,
#   4778,
#   485,
#   24172,
#   912,
#   7088,
#   2514,
#   948,
#   11064,
#   2427,
#   15068,
#   14622,
#   10207,
#   450,
#   133,
#   12060,
#   7239,
#   6598,
#   12297,
#   4778,
#   485,
#   24172,
#   912,
#   7088,
#   2514,
#   948,
#   15068,
#   14622,
#   10207,
#   450,
#   133,
#   6598,
#   7239,
#   485,
#   12297,
#   4778,
#   24172,
#   20300,
#   912,
#   7088,
#   2514,
#   948,
#   11064,
#   20027,
#   15068,
#   14622,
#   10207,
#   12060,
#   6598,
#   450,
#   133,
#   485,
#   12297,
#   4778,
#   24172,
#   7088,
#   948,
#   11064,
#   20027,
#   12060,
#   14622,
#   450,
#   133,
#   12060,
#   6598,
#   485,
#   12297,
#   4778,
#   24172,
#   20300,
#   912,
#   7088,
#   948,
#   11064,
#   53722,
#   20027,
#   15068,
#   485,
#   6598,
#   4778,
#   24172,
#   20300,
#   948,
#   11064,
#   20027,
#   12060,
#   14622,
#   450,
#   6598,
#   4778,
#   24172,
#   20300,
#   948,
#   20027,
#   14622,
#   948,
#   485,
#   450,
#   485,
#   6598,
#   24172,
#   20300,
#   53722,
#   20027,
#   14622,
#   53722,
#   948,
#   24172,
#   20300,
#   450,
#   485,
#   6598,
#   16456,
#   4778,
#   24172,
#   20300,
#   44,
#   30106,
#   948,
#   53723,
#   3832,
#   53722,
#   20027,
#   12060,
#   93,
#   14622,
#   450,
#   485,
#   6598,
#   16456,
#   24172,
#   20300,
#   44,
#   948,
#   53723,
#   3832,
#   30106,
#   20027,
#   93,
#   14622,
#   450,
#   485,
#   16456,
#   24172,
#   20300,
#   44,
#   30106,
#   948,
#   3412,
#   53723,
#   3832,
#   53722,
#   20027,
#   93,
#   14622,
#   16456,
#   24172,
#   20300,
#   44,
#   30106,
#   53722,
#   20027,
#   93,
#   24172,
#   20300,
#   44,
#   30106,
#   948,
#   3412,
#   53723,
#   3832,
#   53722,
#   20027,
#   93,
#   16456,
#   24172,
#   20300,
#   44,
#   3412,
#   3832,
#   53722,
#   53723,
#   93,
#   122,
#   16456,
#   24172,
#   20300,
#   44,
#   30106,
#   625,
#   3412,
#   13141,
#   53723,
#   3832,
#   53722,
#   20027,
#   16456,
#   20300,
#   625,
#   3412,
#   3832,
#   30106,
#   53723,
#   93,
#   122,
#   16456,
#   24172,
#   20300,
#   44,
#   625,
#   ...])

# %%
a = [1,2,3]
a = a[:9]
print(a)
# Out:
# [1, 2, 3]

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)#is [[x],[y]] both len=1000*windowsize
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6196 0.0312 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6125 0.0289 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4938 0.0292 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6325 0.0291 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5005 0.0291 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5448 0.0292 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5499 0.0293 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5748 0.0294 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4745 0.0291 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4331 0.0291 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5125 0.0302 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3824 0.0288 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3230 0.0291 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2141 0.0289 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1723 0.0291 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1534 0.0292 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1119 0.0291 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0644 0.0291 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9934 0.0291 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9689 0.0290 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8748 0.0301 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8840 0.0292 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8712 0.0292 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8428 0.0292 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8225 0.0292 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8179 0.0295 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8198 0.0293 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7811 0.0292 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7843 0.0292 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7632 0.0294 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7744 0.0301 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7748 0.0292 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7201 0.0292 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7085 0.0292 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7754 0.0290 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6965 0.0290 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6869 0.0291 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7208 0.0291 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6869 0.0288 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6610 0.0290 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6739 0.0300 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6850 0.0291 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6161 0.0289 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6361 0.0292 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6640 0.0292 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6445 0.0289 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6087 0.0216 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5429 0.0293 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5264 0.0293 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4947 0.0293 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5018 0.0298 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5217 0.0290 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4625 0.0290 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5156 0.0289 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4848 0.0291 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4757 0.0291 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4679 0.0289 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4034 0.0289 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4452 0.0291 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4371 0.0288 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4390 0.0299 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4068 0.0289 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4461 0.0289 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3797 0.0290 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3936 0.0290 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4522 0.0290 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3704 0.0292 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3686 0.0291 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4071 0.0293 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3704 0.0292 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3663 0.0298 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3918 0.0289 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3827 0.0288 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3596 0.0291 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4009 0.0288 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3759 0.0289 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4083 0.0288 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3835 0.0287 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3529 0.0288 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3310 0.0289 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3384 0.0297 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2832 0.0289 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3649 0.0291 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3954 0.0286 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3778 0.0290 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2920 0.0291 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3385 0.0289 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3288 0.0289 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2198 0.0292 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2827 0.0291 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3178 0.0299 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2995 0.0291 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3329 0.0132 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2604 0.0291 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2443 0.0291 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2260 0.0290 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2053 0.0290 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2279 0.0288 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2063 0.0289 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1587 0.0292 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2485 0.0300 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2453 0.0291 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2440 0.0292 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1598 0.0289 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1967 0.0292 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2037 0.0289 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.2144 0.0292 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1906 0.0292 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1877 0.0290 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1981 0.0293 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1643 0.0300 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2162 0.0291 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1877 0.0292 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1672 0.0290 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1573 0.0289 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1855 0.0293 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2040 0.0289 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1529 0.0290 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1518 0.0291 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2055 0.0290 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2091 0.0299 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1664 0.0290 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1861 0.0290 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1912 0.0290 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1615 0.0290 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1279 0.0290 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1897 0.0289 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1461 0.0291 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1884 0.0290 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2236 0.0290 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2194 0.0299 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1497 0.0291 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1527 0.0287 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1552 0.0288 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0442 0.0292 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1319 0.0290 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1474 0.0289 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1282 0.0290 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1721 0.0050 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1293 0.0289 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0797 0.0299 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0953 0.0288 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0886 0.0290 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0483 0.0288 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1022 0.0289 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9904 0.0291 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1104 0.0291 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0866 0.0291 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1067 0.0288 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0398 0.0288 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0411 0.0297 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0425 0.0291 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0312 0.0287 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0696 0.0287 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0628 0.0289 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0563 0.0287 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0670 0.0286 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1011 0.0289 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0429 0.0289 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0276 0.0288 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0547 0.0298 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0648 0.0290 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0682 0.0290 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0785 0.0291 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0623 0.0293 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0653 0.0288 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0435 0.0289 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0586 0.0288 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0920 0.0287 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0788 0.0290 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0386 0.0297 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0266 0.0290 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0226 0.0290 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0134 0.0289 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0761 0.0288 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1415 0.0290 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1203 0.0286 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0286 0.0289 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0290 0.0288 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0713 0.0291 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9929 0.0301 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0170 0.0291 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0340 0.0292 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0591 0.0289 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0788 0.0289 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0423 0.0259 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0209 0.0290 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0019 0.0292 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0247 0.0287 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9816 0.0289 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9968 0.0299 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9683 0.0289 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0373 0.0289 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0260 0.0288 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0235 0.0287 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0164 0.0289 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9052 0.0292 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9285 0.0288 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9263 0.0291 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9803 0.0290 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0052 0.0301 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0235 0.0288 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9610 0.0289 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0223 0.0288 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0065 0.0286 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9610 0.0288 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9888 0.0288 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9826 0.0289 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9693 0.0287 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0091 0.0287 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9953 0.0298 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0241 0.0288 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9717 0.0288 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0240 0.0290 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9831 0.0291 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9999 0.0290 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9798 0.0290 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9577 0.0288 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9562 0.0287 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0294 0.0288 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# ...
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8367 0.0311 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8291 0.0299 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8325 0.0299 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8445 0.0300 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8392 0.0300 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8600 0.0301 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8778 0.0302 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8282 0.0300 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8827 0.0299 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8519 0.0300 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8648 0.0312 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8656 0.0302 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7933 0.0308 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8345 0.0300 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8862 0.0300 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8383 0.0300 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9587 0.0301 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9174 0.0303 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9142 0.0303 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8320 0.0302 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8065 0.0309 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8813 0.0306 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7567 0.0299 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8849 0.0298 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8489 0.0298 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8330 0.0304 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8896 0.0147 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8293 0.0299 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8281 0.0297 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8209 0.0299 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8096 0.0308 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8336 0.0298 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8119 0.0299 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7621 0.0298 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8739 0.0299 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8368 0.0298 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9039 0.0299 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7656 0.0297 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7987 0.0298 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8347 0.0298 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7452 0.0305 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8146 0.0299 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8512 0.0300 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8217 0.0300 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8006 0.0301 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8841 0.0299 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8393 0.0299 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8020 0.0300 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8234 0.0299 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8472 0.0298 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8738 0.0310 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8439 0.0296 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8342 0.0299 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8646 0.0298 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8505 0.0297 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8632 0.0299 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8355 0.0300 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8870 0.0298 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8274 0.0298 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8144 0.0298 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8770 0.0307 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8105 0.0298 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8945 0.0301 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9084 0.0299 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9031 0.0297 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8409 0.0300 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8013 0.0298 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8044 0.0298 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7147 0.0299 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8681 0.0298 sec/batch
# Nearest to three: hungarian, situating, priorities, yungay, oscar, handmade, ric, astral,
# Nearest to system: machines, soaps, ambivalence, prabang, brest, jogging, vi, magnification,
# Nearest to world: reply, diamonds, vixen, srinagar, collie, debris, dag, donning,
# Nearest to about: marsalis, vizier, treatments, loss, reinforces, josefa, baggins, bangladeshi,
# Nearest to most: madness, monody, rigdon, prog, parameters, aa, besieges, coincidental,
# Nearest to as: eretz, gcc, pascal, logs, fright, ventricular, annapolis, cassini,
# Nearest to had: kaaba, cursor, chan, vasoconstriction, mahatma, batmobile, flanagan, aedicula,
# Nearest to an: protrudes, breckinridge, nativist, potters, sauce, sterreichische, hinder, sabian,
# Nearest to gold: furtherance, bayonet, cip, assyrians, seers, stalagmites, topographical, whitehead,
# Nearest to orthodox: philokalia, webmaster, programme, tente, hoax, nobis, pointy, winslow,
# Nearest to egypt: kungliga, arapaho, felidae, inaction, halakhah, jg, dmitry, ruffians,
# Nearest to numerous: cmt, transitively, mechanical, sundance, usual, nim, synopsis, totoro,
# Nearest to magazine: graphe, sands, groklaw, ashford, levitt, gouged, bronchitis, shamanism,
# Nearest to bill: bernstein, kurtz, christianised, cpl, afterglow, knower, divinities, enantiomers,
# Nearest to universe: salvador, tptp, combustion, encrypt, websphere, benjamins, galtieri, ingrid,
# Nearest to primarily: dispatches, parr, sari, verdean, camelot, disadvantages, quoting, noise,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8335 0.0307 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8549 0.0298 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# ## HW
# #### 1. train your own word2vec model with other dataset
# #### 2. visualize word vectors of your model
# #### 3. highlight/find some interesting embeddings
