# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
#
# First up, importing packages.

# %%
# !wget https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/utils.py
# Out:
# --2018-08-16 16:51:57--  https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... failed: Operation timed out.
# Retrying.
#
# --2018-08-16 16:53:30--  (try: 2)  https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/utils.py
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... failed: Network is unreachable.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /Users/chenxijia/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-12851d1573f6> in <module>()
#       4 import tensorflow as tf
#       5
# ----> 6 import utils
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

if not isfile(dataset_filename):
    urlretrieve(
          'http://mattmahoney.net/dc/text8.zip',
          dataset_filename)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
print(text)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here create dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]#every word's position in the input vector

# %%
print (int_to_vocab)
# Out:
# {0: 'the', 1: 'of', 2: 'and', 3: 'one', 4: 'in', 5: 'a', 6: 'to', 7: 'zero', 8: 'nine', 9: 'two', 10: 'is', 11: 'as', 12: 'eight', 13: 'for', 14: 's', 15: 'five', 16: 'three', 17: 'was', 18: 'by', 19: 'that', 20: 'four', 21: 'six', 22: 'seven', 23: 'with', 24: 'on', 25: 'are', 26: 'it', 27: 'from', 28: 'or', 29: 'his', 30: 'an', 31: 'be', 32: 'this', 33: 'which', 34: 'at', 35: 'he', 36: 'also', 37: 'not', 38: 'have', 39: 'were', 40: 'has', 41: 'but', 42: 'other', 43: 'their', 44: 'its', 45: 'first', 46: 'they', 47: 'some', 48: 'had', 49: 'all', 50: 'more', 51: 'most', 52: 'can', 53: 'been', 54: 'such', 55: 'many', 56: 'who', 57: 'new', 58: 'used', 59: 'there', 60: 'after', 61: 'when', 62: 'into', 63: 'american', 64: 'time', 65: 'these', 66: 'only', 67: 'see', 68: 'may', 69: 'than', 70: 'world', 71: 'i', 72: 'b', 73: 'would', 74: 'd', 75: 'no', 76: 'however', 77: 'between', 78: 'about', 79: 'over', 80: 'years', 81: 'states', 82: 'people', 83: 'war', 84: 'during', 85: 'united', 86: 'known', 87: 'if', 88: 'called', 89: 'use', 90: 'th', 91: 'system', 92: 'often', 93: 'state', 94: 'so', 95: 'history', 96: 'will', 97: 'up', 98: 'while', 99: 'where', 100: 'city', 101: 'being', 102: 'english', 103: 'then', 104: 'any', 105: 'both', 106: 'under', 107: 'out', 108: 'made', 109: 'well', 110: 'her', 111: 'e', 112: 'number', 113: 'government', 114: 'them', 115: 'm', 116: 'later', 117: 'since', 118: 'him', 119: 'part', 120: 'name', 121: 'c', 122: 'century', 123: 'through', 124: 'because', 125: 'x', 126: 'university', 127: 'early', 128: 'life', 129: 'british', 130: 'year', 131: 'like', 132: 'same', 133: 'including', 134: 'became', 135: 'example', 136: 'day', 137: 'each', 138: 'even', 139: 'work', 140: 'language', 141: 'although', 142: 'several', 143: 'form', 144: 'john', 145: 'u', 146: 'national', 147: 'very', 148: 'much', 149: 'g', 150: 'french', 151: 'before', 152: 'general', 153: 'what', 154: 't', 155: 'against', 156: 'n', 157: 'high', 158: 'links', 159: 'could', 160: 'based', 161: 'those', 162: 'now', 163: 'second', 164: 'de', 165: 'music', 166: 'another', 167: 'large', 168: 'she', 169: 'f', 170: 'external', 171: 'german', 172: 'different', 173: 'modern', 174: 'great', 175: 'do', 176: 'common', 177: 'set', 178: 'list', 179: 'south', 180: 'series', 181: 'major', 182: 'game', 183: 'power', 184: 'long', 185: 'country', 186: 'king', 187: 'law', 188: 'group', 189: 'film', 190: 'still', 191: 'until', 192: 'north', 193: 'international', 194: 'term', 195: 'we', 196: 'end', 197: 'book', 198: 'found', 199: 'own', 200: 'political', 201: 'party', 202: 'order', 203: 'usually', 204: 'president', 205: 'church', 206: 'you', 207: 'death', 208: 'theory', 209: 'area', 210: 'around', 211: 'include', 212: 'god', 213: 'ii', 214: 'way', 215: 'did', 216: 'military', 217: 'population', 218: 'using', 219: 'though', 220: 'small', 221: 'following', 222: 'within', 223: 'non', 224: 'human', 225: 'left', 226: 'main', 227: 'among', 228: 'point', 229: 'r', 230: 'due', 231: 'p', 232: 'considered', 233: 'public', 234: 'popular', 235: 'computer', 236: 'west', 237: 'family', 238: 'east', 239: 'information', 240: 'important', 241: 'european', 242: 'man', 243: 'sometimes', 244: 'right', 245: 'old', 246: 'free', 247: 'word', 248: 'without', 249: 'last', 250: 'us', 251: 'members', 252: 'given', 253: 'times', 254: 'roman', 255: 'make', 256: 'h', 257: 'age', 258: 'place', 259: 'l', 260: 'thus', 261: 'science', 262: 'case', 263: 'become', 264: 'systems', 265: 'union', 266: 'born', 267: 'york', 268: 'line', 269: 'countries', 270: 'does', 271: 'isbn', 272: 'st', 273: 'control', 274: 'various', 275: 'others', 276: 'house', 277: 'article', 278: 'island', 279: 'should', 280: 'led', 281: 'back', 282: 'period', 283: 'player', 284: 'europe', 285: 'languages', 286: 'central', 287: 'water', 288: 'few', 289: 'western', 290: 'home', 291: 'began', 292: 'generally', 293: 'less', 294: 'k', 295: 'similar', 296: 'written', 297: 'original', 298: 'best', 299: 'must', 300: 'according', 301: 'school', 3 ...

# %%
int_words
# Out:
# [5233,
#  3080,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10571,
#  133,
#  0,
#  27349,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15067,
#  58112,
#  1,
#  0,
#  150,
#  854,
#  3580,
#  0,
#  194,
#  10,
#  190,
#  58,
#  4,
#  5,
#  10712,
#  214,
#  6,
#  1324,
#  104,
#  454,
#  19,
#  58,
#  2731,
#  362,
#  6,
#  3672,
#  0,
#  708,
#  1,
#  371,
#  26,
#  40,
#  36,
#  53,
#  539,
#  97,
#  11,
#  5,
#  1423,
#  2757,
#  18,
#  567,
#  686,
#  7088,
#  0,
#  247,
#  5233,
#  10,
#  1052,
#  27,
#  0,
#  320,
#  248,
#  44611,
#  2877,
#  792,
#  186,
#  5233,
#  11,
#  5,
#  200,
#  602,
#  10,
#  0,
#  1134,
#  19,
#  2621,
#  25,
#  8983,
#  2,
#  279,
#  31,
#  4147,
#  141,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  153,
#  32,
#  362,
#  5233,
#  36,
#  1137,
#  6,
#  447,
#  344,
#  1818,
#  19,
#  4860,
#  0,
#  6753,
#  1,
#  7573,
#  1774,
#  566,
#  0,
#  93,
#  0,
#  247,
#  11064,
#  11,
#  51,
#  7088,
#  89,
#  26,
#  270,
#  37,
#  5948,
#  4861,
#  20299,
#  28,
#  53721,
#  41,
#  317,
#  5,
#  25636,
#  527,
#  7573,
#  371,
#  4,
#  258,
#  1,
#  153,
#  25,
#  1206,
#  11,
#  7573,
#  200,
#  1576,
#  2,
#  15200,
#  332,
#  1774,
#  7088,
#  4860,
#  344,
#  764,
#  160,
#  406,
#  5690,
#  755,
#  1,
#  4105,
#  1131,
#  4331,
#  1536,
#  2,
#  567,
#  8117,
#  98,
#  5233,
#  10,
#  51,
#  1407,
#  686,
#  18,
#  153,
#  26,
#  10,
#  155,
#  7088,
#  36,
#  2033,
#  1423,
#  8174,
#  1,
#  153,
#  46,
#  693,
#  6,
#  31,
#  5,
#  4148,
#  246,
#  371,
#  76,
#  948,
#  78,
#  310,
#  30,
#  4778,
#  371,
#  507,
#  139,
#  2312,
#  3553,
#  364,
#  23,
#  1821,
#  6,
#  1902,
#  59,
#  10,
#  36,
#  8399,
#  78,
#  310,
#  5,
#  246,
#  371,
#  507,
#  31,
#  753,
#  78,
#  1732,
#  2,
#  8040,
#  24172,
#  2,
#  275,
#  1693,
#  19,
#  151,
#  1032,
#  95,
#  224,
#  371,
#  17,
#  1813,
#  24,
#  4778,
#  1556,
#  51,
#  8118,
#  1465,
#  24172,
#  2,
#  12743,
#  4,
#  6130,
#  19,
#  4187,
#  21148,
#  2427,
#  39,
#  16455,
#  2,
#  7239,
#  861,
#  1,
#  1193,
#  10207,
#  2514,
#  28,
#  15068,
#  187,
#  2,
#  48,
#  1123,
#  912,
#  6,
#  1049,
#  467,
#  12297,
#  7088,
#  133,
#  0,
#  0,
#  11064,
#  3055,
#  2,
#  12060,
#  734,
#  4778,
#  6598,
#  4,
#  14622,
#  27,
#  450,
#  485,
#  24172,
#  198,
#  295,
#  948,
#  4,
#  20027,
#  20300,
#  1,
#  53722,
#  300,
#  6,
#  24172,
#  20300,
#  16456,
#  0,
#  30106,
#  1,
#  0,
#  93,
#  44,
#  3832,
#  2,
#  53723,
#  2,
#  3807,
#  0,
#  3412,
#  1,
#  0,
#  1776,
#  187,
#  1,
#  0,
#  625,
#  0,
#  13141,
#  1,
#  3,
#  21,
#  90,
#  122,
#  284,
#  25,
#  243,
#  232,
#  6,
#  31,
#  436,
#  26184,
#  1,
#  173,
#  5233,
#  7699,
#  2534,
#  4,
#  29,
#  95,
#  1,
#  289,
#  602,
#  4308,
#  19,
#  0,
#  13141,
#  16456,
#  49,
#  187,
#  117,
#  46,
#  359,
#  19,
#  0,
#  384,
#  242,
#  96,
#  31,
#  5234,
#  34,
#  331,
#  2723,
#  18,
#  0,
#  838,
#  1376,
#  27,
#  32,
#  8761,
#  46,
#  6470,
#  34,
#  3243,
#  0,
#  27349,
#  28,
#  551,
#  42432,
#  39,
#  30,
#  127,
#  53724,
#  435,
#  84,
#  0,
#  64,
#  1,
#  0,
#  102,
#  462,
#  83,
#  2,
#  25,
#  232,
#  18,
#  47,
#  11,
#  26184,
#  1,
#  173,
#  5233,
#  4,
#  0,
#  173,
#  839,
#  0,
#  45,
#  6,
#  89,
#  0,
#  194,
#  6,
#  1014,
#  1043,
#  42,
#  69,
#  4861,
#  17,
#  936,
#  14920,
#  4571,
#  164,
#  4,
#  29,
#  40561,
#  11815,
#  22892,
#  259,
#  1225,
#  58113,
#  3,
#  22,
#  7,
#  16,
#  99,
#  35,
#  628,
#  0,
#  2662,
#  63,
#  371,
#  33,
#  48,
#  75,
#  93,
#  687,
#  14777,
#  4044,
#  28,
#  817,
#  917,
#  11,
#  101,
#  4,
#  11064,
#  2534,
#  362,
#  5,
#  6054,
#  2,
#  662,
#  4,
#  0,
#  63,
#  701,
#  435,
#  40,
#  4218,
#  1289,
#  19,
#  35,
#  10,
#  30,
#  4778,
#  2,
#  94,
#  25,
#  49,
#  29,
#  5212,
#  4,
#  3,
#  22,
#  8,
#  16,
#  4,
#  0,
#  5348,
#  1,
#  0,
#  150,
#  854,
#  467,
#  12297,
#  334,
#  30,
#  17194,
#  2434,
#  200,
#  1293,
#  141,
#  12297,
#  215,
#  37,
#  89,
#  0,
#  247,
#  5233,
#  55,
#  116,
#  7088,
#  38,
#  1206,
#  32,
#  197,
#  11,
#  0,
#  45,
#  181,
#  4778,
#  529,
#  2,
#  12297,
#  11,
#  0,
#  1834,
#  1,
#  1912,
#  5233,
#  41,
#  34,
#  32,
#  228,
#  75,
#  4778,
#  435,
#  733,
#  2399,
#  2,
#  0,
#  194,
#  17,
#  86,
#  1073,
#  11,
#  30,
#  14022,
#  30107,
#  18,
#  0,
#  12061,
#  58114,
#  34,
#  50,
#  2419,
#  616,
#  4,
#  0,
#  150,
#  854,
#  0,
#  45,
#  567,
#  8716,
#  4778,
#  2935,
#  1033,
#  14497,
#  26,
#  10,
#  636,
#  359,
#  19,
#  26,
#  5385,
#  154,
#  191,
#  2935,
#  1033,
#  14497,
#  334,
#  153,
#  10,
#  917,
#  4,
#  3,
#  12,
#  20,
#  7,
#  19,
#  0,
#  194,
#  4778,
#  17,
#  989,
#  11,
#  5,
#  567,
#  1606,
#  26,
#  10,
#  13,
#  32,
#  890,
#  19,
#  47,
#  848,
#  14497,
#  11,
#  0,
#  1834,
#  1,
#  173,
#  4778,
#  208,
#  4,
#  153,
#  10,
#  917,
#  14497,
#  5463,
#  23,
#  0,
#  419,
#  12953,
#  917,
#  10,
#  6878,
#  4,
#  32,
#  139,
#  35,
#  1346,
#  0,
#  2878,
#  1,
#  15068,
#  917,
#  154,
#  99,
#  3465,
#  38,
#  652,
#  445,
#  6,
#  89,
#  2,
#  3133,
#  43,
#  917,
#  11,
#  46,
#  3591,
#  54,
#  11,
#  15347,
#  1555,
#  13,
#  2965,
#  4,
#  44,
#  258,
#  14497,
#  1164,
#  153,
#  35,
#  88,
#  3221,
#  1131,
#  52,
#  38,
#  751,
#  445,
#  6,
#  89,
#  1049,
#  522,
#  2,
#  1791,
#  4,
#  5805,
#  23,
#  1556,
#  1,
#  5128,
#  2,
#  1293,
#  14497,
#  14,
#  2654,
#  1,
#  11064,
#  33,
#  35,
#  88,
#  29372,
#  966,
#  30,
#  1334,
#  518,
#  99,
#  1131,
#  2,
#  308,
#  159,
#  512,
#  0,
#  805,
#  1,
#  43,
#  1258,
#  218,
#  1258,
#  1037,
#  33,
#  1391,
#  0,
#  908,
#  1,
#  741,
#  64,
#  966,
#  4,
#  442,
#  32,
#  73,
#  2913,
#  19,
#  75,
#  3,
#  73,
#  2965,
#  27,
#  0,
#  1258,
#  1,
#  275,
#  1555,
#  159,
#  4319,
#  2518,
#  498,
#  4,
#  727,
#  10638,
#  18741,
#  30,
#  762,
#  246,
#  986,
#  73,
#  31,
#  177,
#  97,
#  6,
#  740,
#  3272,
#  23,
#  912,
#  6,
#  0,
#  362,
#  1,
#  442,
#  14497,
#  14,
#  948,
#  39,
#  2025,
#  222,
#  150,
#  741,
#  476,
#  1818,
#  2,
#  29,
#  2985,
#  39,
#  1021,
#  4,
#  0,
#  854,
#  1,
#  3,
#  12,
#  20,
#  12,
#  4,
#  302,
#  14497,
#  14,
#  602,
#  1,
#  917,
#  10,
#  647,
#  26,
#  17,
#  347,
#  4,
#  5,
#  112,
#  1,
#  311,
#  79,
#  29,
#  3567,
#  2,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  47,
#  1,
#  29,
#  948,
#  13,
#  50,
#  2158,
#  1589,
#  67,
#  621,
#  2749,
#  26185,
#  14,
#  15643,
#  4,
#  29,
#  0,
#  10464,
#  2,
#  44,
#  199,
#  26185,
#  1460,
#  19,
#  51,
#  636,
#  1045,
#  344,
#  1774,
#  133,
#  0,
#  2581,
#  1,
#  93,
#  917,
#  11,
#  5,
#  244,
#  389,
#  445,
#  4,
#  152,
#  2,
#  0,
#  147,
#  2581,
#  1,
#  371,
#  39,
#  4579,
#  20847,
#  28,
#  9216,
#  4,
#  0,
#  940,
#  1974,
#  1,
#  371,
#  19,
#  0,
#  1131,
#  25,
#  44,
#  1728,
#  35,
#  5213,
#  15643,
#  2,
#  5,
#  143,
#  1,
#  4,
#  33,
#  1131,
#  73,
#  9711,
#  4,
#  5825,
#  1,
#  50095,
#  66,
#  61,
#  26,
#  17,
#  4,
#  43,
#  567,
#  762,
#  6,
#  175,
#  94,
#  13,
#  118,
#  917,
#  684,
#  1145,
#  78,
#  123,
#  507,
#  13042,
#  5567,
#  310,
#  6,
#  369,
#  6,
#  4106,
#  0,
#  1797,
#  6,
#  118,
#  5464,
#  917,
#  2,
#  153,
#  71,
#  38,
#  4,
#  608,
#  183,
#  19,
#  10,
#  608,
#  199,
#  94,
#  184,
#  11,
#  71,
#  6187,
#  9033,
#  11,
#  7183,
#  71,
#  1225,
#  0,
#  33800,
#  1,
#  0,
#  1797,
#  26185,
#  363,
#  88,
#  391,
#  30,
#  4778,
#  35,
#  1045,
#  66,
#  0,
#  2757,
#  42433,
#  2068,
#  29,
#  948,
#  39,
#  2025,
#  24,
#  55,
#  9929,
#  7088,
#  141,
#  4186,
#  1,
#  29,
#  501,
#  25,
#  3235,
#  63,
#  10270,
#  5233,
#  3244,
#  9606,
#  4,
#  3,
#  ...]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-44b472f17c36> in <module>()
#       3
#       4 threshold = 1e-5
# ----> 5 word_counts = Counter(int_words)
#       6 total_count = len(int_words)
#       7 freqs = {word: count/total_count for word, count in word_counts.items()}
#
# NameError: name 'int_words' is not defined

# %%
word_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa21b432ae7d> in <module>()
# ----> 1 word_counts
#
# NameError: name 'word_counts' is not defined

# %%
len(train_words)
# Out:
# 4627811

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    R,res,i = np.random.randint(1, window_size+1),[words[idx]],1
    while i<=R:
        if idx-i>=0:words.insert(0, words[idx-i])
        if index+i<len(words):words.append(words[index+i])
        i+=1
    return list(set(res))

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):#words = train_words
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    print (len(words))
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]# is the position of certain word
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)#batch_y like [2,4,10,3], each is the 2 nearest word
            x.extend([batch_x]*len(batch_y))#[batch_x]*len(batch_y) like [5,5,5,5], 5 is the input word
            #why need window-size of x? because we need to generate window-size of y, so need window-size time softmax
        yield x, y# x's size is 1000*(2*window_size)

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](https://raw.githubusercontent.com/udacity/deep-learning/master/embeddings/assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
#  Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))#4628128*200 matrix
    embed = tf.nn.embedding_lookup(embedding, inputs)#1*200 vector for every word

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))#soft max param
    softmax_b = tf.Variable(tf.zeros(n_vocab))#soft max param
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
x = tf.constant([[1, 1, 1], [1, 1, 1]])
sum = tf.reduce_sum(x, 1, keepdims=True)
with tf.Session() as sess:
    print(sum.eval())
  # [[3], [3]]
# Out:
# [[3]
#  [3]]

# %%
x = tf.constant([[1, 1, 1], [2, 2, 2],[3,3,3]])
valid = tf.constant([1,2])
res = tf.nn.embedding_lookup(x,valid)
print(res)    
with tf.Session() as sess:
    print(res.eval())
# Out:
# Tensor("embedding_lookup:0", shape=(2, 3), dtype=int32)
# [[2 2 2]
#  [3 3 3]]

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)#is a 16*200 matrix
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
    #(16*200)*(200*63641)matrix 
    #in the 16*63641 matrix, each element is the similarity between the one of 16 word with one of the 63641 word
    # more similar, then this value is bigger.
# Out:
# WARNING:tensorflow:From <ipython-input-21-420750dd553c>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
similarity
# Out:
# <tf.Tensor 'MatMul:0' shape=(16, 63641) dtype=float32>

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
batches = get_batches(train_words, 1000, 10)
next(batches)
# for i in batches:
#     print(i)
# Out:
# 4627000
# ([5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   10571,
#   10571,
#   10571,
#   10571,
#   10571,
#   10571,
#   10571,
#   27349,
#   27349,
#   27349,
#   27349,
#   15067,
#   15067,
#   15067,
#   15067,
#   15067,
#   15067,
#   15067,
#   15067,
#   58112,
#   58112,
#   58112,
#   58112,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   3580,
#   194,
#   194,
#   194,
#   194,
#   194,
#   194,
#   194,
#   194,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   10712,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   3672,
#   708,
#   708,
#   708,
#   708,
#   708,
#   708,
#   708,
#   708,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   371,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   40,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   539,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   2757,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   7088,
#   7088,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   1052,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   44611,
#   2877,
#   2877,
#   5233,
#   5233,
#   5233,
#   5233,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   11,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   8983,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   4147,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   59,
#   6437,
#   6437,
#   6437,
#   6437,
#   6437,
#   6437,
#   4186,
#   4186,
#   4186,
#   4186,
#   4186,
#   4186,
#   4186,
#   4186,
#   4186,
#   4186,
#   32,
#   32,
#   32,
#   32,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   5233,
#   1137,
#   1137,
#   1137,
#   1137,
#   1137,
#   1137,
#   1818,
#   1818,
#   1818,
#   1818,
#   1818,
#   1818,
#   1818,
#   1818,
#   1818,
#   1818,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   4860,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   6753,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   51,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   5948,
#   4861,
#   4861,
#   4861,
#   4861,
#   4861,
#   4861,
#   20299,
#   20299,
#   20299,
#   20299,
#   20299,
#   20299,
#   53721,
#   53721,
#   53721,
#   53721,
#   53721,
#   53721,
#   53721,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   25636,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   7573,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   1576,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   15200,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   1774,
#   4860,
#   4860,
#   344,
#   344,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   764,
#   5690,
#   5690,
#   755,
#   755,
#   755,
#   755,
#   4105,
#   4105,
#   4105,
#   4105,
#   4105,
#   4105,
#   4105,
#   4105,
#   4105,
#   4105,
#   4331,
#   4331,
#   4331,
#   4331,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   567,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   8117,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   153,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   2033,
#   2033,
#   2033,
#   2033,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   8174,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   4148,
#   30,
#   30,
#   30,
#   30,
#   30,
#   30,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   3553,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1821,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   1902,
#   36,
#   36,
#   36,
#   36,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   8399,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   310,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   507,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   1732,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   8040,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   1693,
#   1693,
#   1693,
#   1693,
#   1693,
#   1693,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   1813,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   4778,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   8118,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   24172,
#   12743,
#   12743,
#   6130,
#   6130,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   4187,
#   21148,
#   21148,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   16455,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   7239,
#   1193,
#   1193,
#   1193,
#   1193,
#   1193,
#   1193,
#   1193,
#   1193,
#   1193,
#   1193,
#   10207,
#   10207,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   2514,
#   15068,
#   15068,
#   15068,
#   15068,
#   1049,
#   1049,
#   12297,
#   12297,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   7088,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   11064,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   3055,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   12060,
#   734,
#   734,
#   734,
#   734,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   6598,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   14622,
#   485,
#   485,
#   485,
#   485,
#   ...],
#  [58112,
#   194,
#   708,
#   6,
#   10571,
#   3672,
#   27349,
#   10712,
#   15067,
#   3580,
#   58112,
#   194,
#   5233,
#   27349,
#   10712,
#   15067,
#   3580,
#   58112,
#   5233,
#   10571,
#   15067,
#   58112,
#   194,
#   6,
#   10571,
#   5233,
#   27349,
#   10712,
#   3580,
#   194,
#   15067,
#   3580,
#   27349,
#   58112,
#   194,
#   708,
#   2757,
#   6,
#   40,
#   10571,
#   3672,
#   5233,
#   371,
#   27349,
#   567,
#   10712,
#   539,
#   15067,
#   58112,
#   708,
#   6,
#   3672,
#   27349,
#   10712,
#   15067,
#   3580,
#   58112,
#   194,
#   708,
#   2757,
#   6,
#   40,
#   10571,
#   5233,
#   371,
#   27349,
#   3672,
#   539,
#   15067,
#   3580,
#   58112,
#   194,
#   708,
#   10712,
#   40,
#   371,
#   3672,
#   3580,
#   58112,
#   194,
#   44611,
#   708,
#   2757,
#   6,
#   40,
#   10571,
#   1052,
#   7088,
#   5233,
#   371,
#   27349,
#   567,
#   10712,
#   539,
#   15067,
#   3580,
#   194,
#   2757,
#   6,
#   40,
#   3672,
#   371,
#   10712,
#   539,
#   194,
#   708,
#   2757,
#   6,
#   40,
#   3672,
#   7088,
#   567,
#   10712,
#   539,
#   58112,
#   194,
#   44611,
#   708,
#   2757,
#   6,
#   3672,
#   11,
#   1052,
#   7088,
#   5233,
#   371,
#   27349,
#   567,
#   10712,
#   539,
#   15067,
#   3580,
#   2877,
#   58112,
#   194,
#   44611,
#   708,
#   2757,
#   6,
#   40,
#   3672,
#   11,
#   1052,
#   7088,
#   5233,
#   371,
#   567,
#   10712,
#   3580,
#   2877,
#   44611,
#   708,
#   6,
#   40,
#   7088,
#   5233,
#   371,
#   567,
#   3672,
#   539,
#   1052,
#   2877,
#   2757,
#   40,
#   7088,
#   5233,
#   539,
#   1052,
#   5233,
#   567,
#   44611,
#   2757,
#   7088,
#   567,
#   1052,
#   2877,
#   44611,
#   2757,
#   40,
#   59,
#   11,
#   8983,
#   7088,
#   5233,
#   371,
#   4147,
#   567,
#   539,
#   2877,
#   2757,
#   59,
#   11,
#   8983,
#   7088,
#   5233,
#   4147,
#   567,
#   539,
#   1052,
#   2877,
#   5233,
#   44611,
#   11,
#   44611,
#   2877,
#   8983,
#   44611,
#   6437,
#   5233,
#   4147,
#   8983,
#   59,
#   1052,
#   2877,
#   32,
#   44611,
#   6437,
#   11,
#   5233,
#   4147,
#   4186,
#   59,
#   1052,
#   2877,
#   32,
#   6753,
#   44611,
#   4860,
#   6437,
#   1818,
#   11,
#   8983,
#   7088,
#   5233,
#   1137,
#   567,
#   4186,
#   59,
#   1052,
#   2877,
#   32,
#   6753,
#   44611,
#   4860,
#   6437,
#   11,
#   7088,
#   5233,
#   1137,
#   4147,
#   8983,
#   11064,
#   4186,
#   1818,
#   1052,
#   2877,
#   32,
#   5233,
#   4147,
#   8983,
#   4186,
#   59,
#   32,
#   6437,
#   11,
#   5233,
#   1137,
#   4147,
#   8983,
#   1818,
#   59,
#   4860,
#   5233,
#   4186,
#   6437,
#   1137,
#   32,
#   6753,
#   6437,
#   1818,
#   1137,
#   4186,
#   59,
#   4860,
#   32,
#   6753,
#   5233,
#   4186,
#   1818,
#   4860,
#   32,
#   6753,
#   6437,
#   7088,
#   5233,
#   1137,
#   51,
#   11064,
#   4186,
#   4860,
#   32,
#   6753,
#   25636,
#   6437,
#   1818,
#   20299,
#   7088,
#   5233,
#   1137,
#   4147,
#   51,
#   8983,
#   11064,
#   53721,
#   4186,
#   59,
#   5948,
#   4861,
#   32,
#   25636,
#   6437,
#   5948,
#   1818,
#   20299,
#   7088,
#   5233,
#   1137,
#   4147,
#   51,
#   7573,
#   8983,
#   11064,
#   53721,
#   4186,
#   59,
#   4860,
#   4861,
#   32,
#   6753,
#   25636,
#   6437,
#   5948,
#   1818,
#   20299,
#   7088,
#   5233,
#   1137,
#   51,
#   7573,
#   53721,
#   4186,
#   59,
#   4860,
#   4861,
#   6753,
#   5948,
#   20299,
#   7088,
#   11064,
#   1818,
#   4860,
#   4861,
#   6753,
#   5948,
#   20299,
#   51,
#   11064,
#   53721,
#   4860,
#   4861,
#   6753,
#   25636,
#   1576,
#   20299,
#   7088,
#   1137,
#   51,
#   7573,
#   11064,
#   53721,
#   1818,
#   4860,
#   4861,
#   25636,
#   20299,
#   7088,
#   51,
#   53721,
#   5948,
#   25636,
#   7088,
#   7573,
#   53721,
#   5948,
#   4861,
#   25636,
#   1576,
#   20299,
#   7088,
#   7573,
#   5948,
#   4861,
#   15200,
#   6753,
#   2,
#   344,
#   764,
#   5948,
#   1576,
#   20299,
#   1774,
#   7088,
#   51,
#   7573,
#   11064,
#   53721,
#   4860,
#   4861,
#   15200,
#   2,
#   25636,
#   4860,
#   1576,
#   20299,
#   1774,
#   7088,
#   7573,
#   53721,
#   5948,
#   4861,
#   15200,
#   6753,
#   2,
#   344,
#   25636,
#   4860,
#   764,
#   1576,
#   4105,
#   20299,
#   1774,
#   7088,
#   51,
#   755,
#   7573,
#   11064,
#   53721,
#   5690,
#   5948,
#   4861,
#   15200,
#   2,
#   25636,
#   764,
#   20299,
#   1774,
#   7573,
#   344,
#   53721,
#   4860,
#   4861,
#   15200,
#   25636,
#   4860,
#   764,
#   1576,
#   4105,
#   20299,
#   4331,
#   1774,
#   7088,
#   755,
#   7573,
#   344,
#   53721,
#   5690,
#   5948,
#   4861,
#   2,
#   25636,
#   764,
#   1576,
#   1774,
#   755,
#   7573,
#   344,
#   53721,
#   5690,
#   4860,
#   15200,
#   2,
#   25636,
#   764,
#   1576,
#   4105,
#   20299,
#   4331,
#   755,
#   7573,
#   344,
#   53721,
#   5690,
#   4860,
#   344,
#   1774,
#   4860,
#   764,
#   15200,
#   2,
#   25636,
#   1576,
#   4105,
#   4331,
#   1774,
#   7088,
#   755,
#   7573,
#   8117,
#   567,
#   344,
#   153,
#   5690,
#   4860,
#   755,
#   764,
#   4105,
#   5690,
#   4331,
#   764,
#   2,
#   764,
#   4331,
#   755,
#   8117,
#   567,
#   344,
#   153,
#   5690,
#   4860,
#   4105,
#   2,
#   755,
#   567,
#   4105,
#   4331,
#   8174,
#   7088,
#   2033,
#   755,
#   8117,
#   567,
#   344,
#   153,
#   5690,
#   764,
#   2,
#   4105,
#   4331,
#   8174,
#   7088,
#   2033,
#   755,
#   4148,
#   8117,
#   344,
#   153,
#   5690,
#   764,
#   30,
#   2,
#   4105,
#   4331,
#   8174,
#   7088,
#   2033,
#   755,
#   4148,
#   567,
#   153,
#   3553,
#   2,
#   764,
#   36,
#   4105,
#   4331,
#   8174,
#   1902,
#   7088,
#   2033,
#   8399,
#   755,
#   4148,
#   8117,
#   567,
#   344,
#   5690,
#   4860,
#   1821,
#   30,
#   3553,
#   2,
#   4105,
#   4331,
#   8174,
#   1902,
#   2033,
#   755,
#   4148,
#   8117,
#   567,
#   153,
#   1821,
#   30,
#   7088,
#   153,
#   4148,
#   8174,
#   3553,
#   7088,
#   2033,
#   4148,
#   8117,
#   153,
#   1821,
#   30,
#   3553,
#   2,
#   36,
#   4331,
#   8174,
#   1902,
#   7088,
#   2033,
#   8399,
#   8117,
#   310,
#   567,
#   153,
#   507,
#   1821,
#   30,
#   3553,
#   8174,
#   1902,
#   2033,
#   4148,
#   1821,
#   36,
#   8174,
#   1902,
#   7088,
#   2033,
#   8399,
#   4148,
#   310,
#   153,
#   507,
#   1821,
#   30,
#   3553,
#   36,
#   1732,
#   8040,
#   24172,
#   8174,
#   1902,
#   7088,
#   2033,
#   8399,
#   4148,
#   8117,
#   310,
#   153,
#   507,
#   30,
#   3553,
#   36,
#   1732,
#   8040,
#   8174,
#   8399,
#   2033,
#   4148,
#   310,
#   507,
#   1821,
#   30,
#   310,
#   1821,
#   1902,
#   8399,
#   3553,
#   36,
#   1732,
#   1693,
#   8040,
#   24172,
#   1902,
#   4148,
#   310,
#   507,
#   1821,
#   30,
#   3553,
#   36,
#   1732,
#   1693,
#   8040,
#   4778,
#   24172,
#   1902,
#   8399,
#   4148,
#   1813,
#   507,
#   1821,
#   30,
#   36,
#   1732,
#   1693,
#   8040,
#   24172,
#   1902,
#   8399,
#   1813,
#   310,
#   1821,
#   3553,
#   36,
#   1693,
#   12743,
#   8040,
#   4778,
#   24172,
#   1902,
#   8399,
#   6130,
#   4148,
#   1813,
#   310,
#   8118,
#   507,
#   1821,
#   30,
#   1732,
#   36,
#   4778,
#   24172,
#   8399,
#   1813,
#   310,
#   8118,
#   507,
#   1693,
#   36,
#   1732,
#   12743,
#   8040,
#   4778,
#   24172,
#   1902,
#   8399,
#   6130,
#   1813,
#   310,
#   8118,
#   507,
#   1693,
#   1732,
#   8040,
#   4778,
#   24172,
#   1813,
#   8118,
#   36,
#   1732,
#   1693,
#   12743,
#   8040,
#   16455,
#   4778,
#   4187,
#   24172,
#   7239,
#   1902,
#   8399,
#   1193,
#   6130,
#   310,
#   8118,
#   507,
#   21148,
#   1821,
#   1732,
#   12743,
#   8040,
#   4187,
#   24172,
#   6130,
#   1813,
#   8118,
#   507,
#   21148,
#   1693,
#   1732,
#   12743,
#   8040,
#   16455,
#   4778,
#   4187,
#   24172,
#   7239,
#   6130,
#   1813,
#   507,
#   21148,
#   1693,
#   12743,
#   4778,
#   6130,
#   1813,
#   8118,
#   4187,
#   6130,
#   24172,
#   4187,
#   12743,
#   12743,
#   16455,
#   7239,
#   4778,
#   1193,
#   24172,
#   6130,
#   2514,
#   1813,
#   8118,
#   21148,
#   10207,
#   4187,
#   16455,
#   15068,
#   12743,
#   7239,
#   1193,
#   4778,
#   12297,
#   24172,
#   6130,
#   2514,
#   8118,
#   1049,
#   4187,
#   21148,
#   10207,
#   15068,
#   12743,
#   16455,
#   1193,
#   12297,
#   24172,
#   7088,
#   6130,
#   2514,
#   8118,
#   1049,
#   4187,
#   21148,
#   10207,
#   15068,
#   7239,
#   16455,
#   12297,
#   6130,
#   2514,
#   1049,
#   4187,
#   21148,
#   10207,
#   1193,
#   2514,
#   15068,
#   12060,
#   6598,
#   12743,
#   16455,
#   7239,
#   1193,
#   12297,
#   24172,
#   3055,
#   7088,
#   6130,
#   11064,
#   1049,
#   4187,
#   21148,
#   734,
#   10207,
#   1049,
#   2514,
#   12297,
#   10207,
#   12297,
#   15068,
#   7088,
#   1049,
#   12060,
#   12297,
#   3055,
#   2514,
#   11064,
#   1049,
#   15068,
#   734,
#   12060,
#   6598,
#   485,
#   12297,
#   14622,
#   3055,
#   7088,
#   2514,
#   1049,
#   15068,
#   734,
#   10207,
#   12060,
#   6598,
#   485,
#   1193,
#   12297,
#   14622,
#   24172,
#   7088,
#   2514,
#   948,
#   11064,
#   1049,
#   20027,
#   15068,
#   734,
#   10207,
#   485,
#   6598,
#   7239,
#   1193,
#   12297,
#   14622,
#   24172,
#   20300,
#   3055,
#   7088,
#   2514,
#   948,
#   11064,
#   1049,
#   53722,
#   20027,
#   15068,
#   734,
#   10207,
#   14622,
#   12060,
#   6598,
#   3055,
#   12060,
#   485,
#   12297,
#   24172,
#   20300,
#   3055,
#   7088,
#   2514,
#   948,
#   11064,
#   1049,
#   53722,
#   20027,
#   15068,
#   734,
#   14622,
#   485,
#   6598,
#   12297,
#   24172,
#   20300,
#   3055,
#   7088,
#   948,
#   11064,
#   1049,
#   53722,
#   20027,
#   12060,
#   734,
#   6598,
#   16456,
#   12297,
#   24172,
#   ...])

# %%
a = [1,2,3]
a = a[:9]
print(a)
# Out:
# [1, 2, 3]

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)#is [[x],[y]] both len=1000*windowsize
        start = time.time()
        for x, y in batches:#4628 times iteration
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# 4627000
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6282 0.0375 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6272 0.0301 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5404 0.0302 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6014 0.0298 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5246 0.0298 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4877 0.0301 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5783 0.0302 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5770 0.0301 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4928 0.0299 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4520 0.0304 sec/batch
# Nearest to this: the, scholz, marischal, pronouncing, digs, shirts, approaches, murders,
# Nearest to be: ucl, abuser, rooting, proleptic, contention, walrus, sodomy, beli,
# Nearest to four: maroon, overtaking, accuracy, estes, sled, ushant, crusher, are,
# Nearest to were: sauce, nyx, archers, loaf, punic, albicans, reflect, proactive,
# Nearest to his: reffered, heats, cartography, tackled, indecision, rudely, trask, cipm,
# Nearest to often: quiz, deformation, marquess, pulsating, mayo, fond, subscalar, reared,
# Nearest to people: literature, clippings, redefine, jethro, bang, buds, zerby, tile,
# Nearest to some: wendt, deceit, bivector, mantled, pilots, surmounted, five, been,
# Nearest to marriage: lookups, morpheus, cowboys, hooker, beekeepers, tenure, eel, brainiac,
# Nearest to discovered: loos, elmhurst, malayan, churn, vibe, hills, musicum, cartographers,
# Nearest to universe: counterargument, unreactive, disperse, profumo, universitat, austrians, christensen, cheung,
# Nearest to orthodox: sinthasomphone, matchups, structures, adjectival, proclaiming, glycosides, resonating, stricken,
# Nearest to notes: fertilization, zuse, antiaircraft, daniels, cummins, dubai, anni, alcoholism,
# Nearest to centre: quixote, infielder, wedged, multilayered, tingling, andrei, voter, boromir,
# Nearest to powers: emerging, boulogne, courtesans, breaks, complications, engset, identity, conyers,
# Nearest to units: jfs, shower, reginald, robotic, immigration, verve, danmarks, cuic,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4874 0.0310 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3841 0.0298 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3440 0.0300 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2157 0.0298 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1811 0.0300 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1605 0.0300 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1129 0.0301 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0570 0.0295 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0125 0.0299 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9817 0.0301 sec/batch
# Nearest to this: the, approaches, by, exercised, murders, pronouncing, digs, anyone,
# Nearest to be: compensation, soldier, ucl, contention, objected, abuser, posterity, should,
# Nearest to four: accuracy, produce, shortly, positions, twelfth, maroon, borderline, ushant,
# Nearest to were: reflect, well, everywhere, sauce, directly, independence, searchable, spellman,
# Nearest to his: tackled, efficient, reflection, lancashire, one, cartography, massacred, cipm,
# Nearest to often: cost, narrower, with, instance, fond, referendum, acquired, quiz,
# Nearest to people: literature, bang, jethro, tile, climax, clippings, redefine, rose,
# Nearest to some: wendt, deceit, pilots, been, variant, plan, frac, bivector,
# Nearest to marriage: lookups, cowboys, psychologists, morpheus, beekeepers, additional, tenure, viewpoint,
# Nearest to discovered: loos, the, hills, route, cartographers, elmhurst, vibe, malayan,
# Nearest to universe: collective, counterargument, austrians, wendy, disperse, tomato, unreactive, profumo,
# Nearest to orthodox: structures, proclaiming, describes, sinthasomphone, adjectival, results, length, matchups,
# Nearest to notes: fertilization, zuse, alert, business, antiaircraft, po, cummins, isn,
# Nearest to centre: quixote, multilayered, infielder, myth, shaken, voter, wedged, facto,
# Nearest to powers: emerging, identity, breaks, boulogne, complications, mentioned, negotiate, spoof,
# Nearest to units: robotic, of, without, immigration, shower, danmarks, jfs, peake,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9417 0.0313 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9241 0.0302 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8878 0.0301 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8706 0.0302 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8154 0.0296 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8214 0.0301 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7900 0.0302 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7940 0.0300 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7882 0.0301 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7860 0.0302 sec/batch
# Nearest to this: approaches, the, by, pronouncing, frances, divides, exercised, anyone,
# Nearest to be: ucl, contention, abuser, objected, plantation, rooting, quine, compensation,
# Nearest to four: maroon, shortly, twelfth, painters, accuracy, starr, banishing, positions,
# Nearest to were: reflect, everywhere, proactive, well, nyx, searchable, archers, sauce,
# Nearest to his: succeeded, one, tackled, lancashire, cartography, reflection, massacred, safe,
# Nearest to often: geologic, quiz, fond, deformation, cost, narrower, with, monstrous,
# Nearest to people: literature, tile, climax, clippings, jethro, bang, redefine, filter,
# Nearest to some: wendt, harnessed, deceit, pilots, rhineland, variant, swings, activists,
# Nearest to marriage: psychologists, tenure, cowboys, morpheus, lookups, additional, hooker, viewpoint,
# Nearest to discovered: loos, hills, the, cartographers, route, vibe, elmhurst, malayan,
# Nearest to universe: collective, austrians, organelles, disperse, wendy, unreactive, counterargument, tomato,
# Nearest to orthodox: structures, proclaiming, sinthasomphone, adjectival, describes, length, shakespeare, landmark,
# Nearest to notes: fertilization, zuse, antiaircraft, alert, business, cummins, alcoholism, multiple,
# Nearest to centre: quixote, multilayered, myth, shaken, installations, voter, infielder, having,
# Nearest to powers: emerging, complications, identity, boulogne, breaks, negotiate, retain, capitalism,
# Nearest to units: robotic, reginald, neighbour, shower, tens, immigration, protected, without,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8067 0.0309 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7642 0.0299 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7148 0.0301 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6958 0.0300 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7519 0.0301 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6880 0.0300 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7076 0.0303 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7029 0.0296 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6840 0.0298 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6896 0.0301 sec/batch
# Nearest to this: approaches, the, pronouncing, frances, divides, by, glue, marischal,
# Nearest to be: abuser, ucl, contention, objected, falun, rooting, sodomy, sturm,
# Nearest to four: seven, banishing, starr, painters, marijuana, twelfth, deaths, maroon,
# Nearest to were: proactive, punic, archers, nyx, well, searchable, magnus, bolshevik,
# Nearest to his: succeeded, lancashire, tackled, rudely, literary, trask, zuid, cipm,
# Nearest to often: geologic, fond, quiz, deformation, cost, expansionism, correlating, reared,
# Nearest to people: literature, clippings, jethro, redefine, tile, buds, bang, climax,
# Nearest to some: wendt, pilots, harnessed, concerted, deceit, swings, rhineland, variant,
# Nearest to marriage: lookups, hooker, cowboys, morpheus, beekeepers, tenure, psychologists, sees,
# Nearest to discovered: loos, hills, elmhurst, cartographers, route, malayan, churn, vibe,
# Nearest to universe: austrians, disperse, organelles, collective, unreactive, wendy, profumo, counterargument,
# Nearest to orthodox: sinthasomphone, structures, proclaiming, magnificently, matchups, favor, resonating, equinox,
# Nearest to notes: zuse, fertilization, antiaircraft, cummins, alcoholism, dubai, po, decapitated,
# Nearest to centre: quixote, multilayered, voter, myth, facto, installations, shaken, andrei,
# Nearest to powers: emerging, complications, breaks, capitalism, retain, identity, conyers, boulogne,
# Nearest to units: robotic, neighbour, udp, shower, reginald, jfs, hindustan, danmarks,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7062 0.0311 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6530 0.0301 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6168 0.0301 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6405 0.0301 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6275 0.0297 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6117 0.0300 sec/batch
# 4627000
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6043 0.0228 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5214 0.0304 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5048 0.0300 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5133 0.0301 sec/batch
# Nearest to this: approaches, the, pronouncing, divides, by, hypothetical, reparation, exterior,
# Nearest to be: abuser, sturm, falun, should, ucl, contention, objected, jabber,
# Nearest to four: seven, banishing, b, painters, deaths, starr, maroon, twelfth,
# Nearest to were: archers, punic, nyx, bessarabia, proactive, well, had, bolshevik,
# Nearest to his: succeeded, lancashire, literary, vengeance, zuid, trask, indecision, apollodorus,
# Nearest to often: geologic, fond, cost, correlating, immigrating, quiz, narrower, reared,
# Nearest to people: literature, clippings, jethro, buds, redefine, tile, climax, christian,
# Nearest to some: harnessed, wendt, pilots, variant, mantled, deceit, rhineland, swings,
# Nearest to marriage: lookups, hooker, morpheus, tenure, beekeepers, cowboys, psychologists, arrival,
# Nearest to discovered: loos, hills, elmhurst, route, cartographers, envisioned, hydronium, vibe,
# Nearest to universe: disperse, organelles, counterargument, unreactive, austrians, wavelet, tomato, profumo,
# Nearest to orthodox: sinthasomphone, matchups, magnificently, resonating, buddha, proclaiming, equinox, favor,
# Nearest to notes: cummins, zuse, fertilization, antiaircraft, alcoholism, decapitated, anni, dubai,
# Nearest to centre: quixote, dona, infielder, installations, multilayered, andrei, myth, facto,
# Nearest to powers: emerging, complications, breaks, conyers, retain, boulogne, capitalism, negotiate,
# Nearest to units: udp, robotic, intuitively, hindustan, halide, neighbour, cuic, shower,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5003 0.0308 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5034 0.0295 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4978 0.0299 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5072 0.0299 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5237 0.0300 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4830 0.0301 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4708 0.0300 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3974 0.0298 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4171 0.0297 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4334 0.0298 sec/batch
# Nearest to this: approaches, the, by, divides, infinite, pronouncing, unpredictable, glue,
# Nearest to be: should, sturm, abuser, contention, religous, encodes, therefore, jabber,
# Nearest to four: zero, seven, reza, banishing, two, weir, pew, twelfth,
# Nearest to were: archers, proactive, had, well, bessarabia, nyx, punic, bolshevik,
# Nearest to his: lancashire, succeeded, vengeance, mangeshkar, literary, works, trask, rudely,
# Nearest to often: geologic, correlating, fond, narrower, cost, practicality, immigrating, instance,
# Nearest to people: literature, clippings, buds, tile, jethro, redefine, nationality, zerby,
# Nearest to some: harnessed, pilots, wendt, variant, kut, mantled, deceit, phonetic,
# Nearest to marriage: lookups, hooker, morpheus, beekeepers, cowboys, tenure, psychologists, arrival,
# Nearest to discovered: loos, elmhurst, hills, cartographers, webcomics, hydronium, dci, burning,
# Nearest to universe: organelles, disperse, unreactive, counterargument, wavelet, beliefs, austrians, tomato,
# Nearest to orthodox: sinthasomphone, matchups, magnificently, buddha, equinox, favor, resonating, scripture,
# Nearest to notes: cummins, fertilization, antiaircraft, zuse, decapitated, alcoholism, anni, berserker,
# Nearest to centre: quixote, dona, infielder, installations, gallery, sandstone, multilayered, shaken,
# Nearest to powers: emerging, complications, capitalism, flit, negotiate, retain, women, conyers,
# Nearest to units: robotic, hindustan, neighbour, intuitively, udp, nonexistence, halide, of,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4322 0.0311 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4160 0.0299 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4531 0.0301 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3781 0.0299 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4326 0.0296 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4526 0.0298 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3596 0.0299 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3902 0.0300 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4058 0.0299 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3510 0.0300 sec/batch
# Nearest to this: the, approaches, by, glue, infinite, quantize, constitutes, pronouncing,
# Nearest to be: should, encodes, sturm, abuser, therefore, objected, contention, religous,
# Nearest to four: zero, two, seven, banishing, six, reza, pew, apologised,
# Nearest to were: archers, had, nyx, bessarabia, bolshevik, punic, proactive, saturnalia,
# Nearest to his: vengeance, succeeded, apollodorus, literary, works, hsls, deceit, eleanor,
# Nearest to often: geologic, correlating, narrower, practicality, deformation, fond, immigrating, primal,
# Nearest to people: literature, clippings, buds, redefine, nationality, tile, zerby, jethro,
# Nearest to some: harnessed, wendt, mantled, variant, kut, pilots, concerted, phonetic,
# Nearest to marriage: hooker, morpheus, beekeepers, lookups, tenure, cowboys, napoli, psychologists,
# Nearest to discovered: loos, hydronium, webcomics, burning, hills, dci, cartographers, elmhurst,
# Nearest to universe: disperse, organelles, unreactive, beliefs, counterargument, wavelet, semitism, universitat,
# Nearest to orthodox: sinthasomphone, buddha, equinox, magnificently, muslim, greeks, scripture, favor,
# Nearest to notes: cummins, antiaircraft, fertilization, decapitated, zuse, informative, alcoholism, berserker,
# Nearest to centre: quixote, installations, infielder, dona, gallery, multilayered, sandstone, shaken,
# Nearest to powers: emerging, negotiate, retain, capitalism, court, flit, complications, succulent,
# Nearest to units: robotic, hindustan, intuitively, nonexistence, standard, udp, neighbour, makeup,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3593 0.0311 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3954 0.0296 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3756 0.0300 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3755 0.0299 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3807 0.0299 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3503 0.0301 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3678 0.0300 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3930 0.0304 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3242 0.0300 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3404 0.0299 sec/batch
# Nearest to this: the, by, approaches, hypothetical, infinite, constitutes, exterior, glue,
# Nearest to be: should, sturm, encodes, abuser, religous, objected, pps, careful,
# Nearest to four: zero, two, seven, six, three, one, five, apologised,
# Nearest to were: archers, had, punic, nyx, bessarabia, bolshevik, realign, proactive,
# Nearest to his: vengeance, succeeded, apollodorus, eleanor, works, indecision, cipm, hsls,
# Nearest to often: geologic, correlating, deformation, practicality, narrower, athabaskan, fond, behaviors,
# Nearest to people: literature, clippings, buds, nationality, redefine, jethro, christian, tile,
# Nearest to some: wendt, harnessed, concerted, variant, pilots, kut, mantled, well,
# Nearest to marriage: hooker, beekeepers, morpheus, lookups, viewpoint, psychologists, tenure, cowboys,
# Nearest to discovered: loos, hydronium, burning, webcomics, arctocephalus, synthetic, dci, cartographers,
# Nearest to universe: organelles, disperse, unreactive, beliefs, counterargument, wavelet, profumo, unwise,
# Nearest to orthodox: buddha, equinox, sinthasomphone, greeks, muslim, pentecost, magnificently, baptist,
# Nearest to notes: cummins, antiaircraft, fertilization, decapitated, informative, berserker, zuse, alcoholism,
# Nearest to centre: quixote, installations, infielder, dona, sandstone, gallery, dhahran, boromir,
# Nearest to powers: emerging, negotiate, dissolution, retain, court, capitalism, succulent, courts,
# Nearest to units: robotic, standard, nonexistence, hindustan, makeup, tens, protected, udp,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3344 0.0312 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2935 0.0301 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3664 0.0301 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3853 0.0301 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3806 0.0300 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2888 0.0299 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3132 0.0300 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3573 0.0302 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2253 0.0302 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3093 0.0303 sec/batch
# Nearest to this: the, approaches, by, cardigan, hypothetical, pronouncing, constitutes, infinite,
# Nearest to be: sturm, encodes, should, abuser, religous, contention, pps, falun,
# Nearest to four: two, zero, seven, six, one, five, three, paved,
# Nearest to were: archers, had, nyx, punic, proactive, bolshevik, bessarabia, saturnalia,
# Nearest to his: vengeance, indecision, succeeded, deceit, apollodorus, works, hsls, tackled,
# Nearest to often: geologic, correlating, athabaskan, practicality, narrower, fond, deformation, immature,
# Nearest to people: literature, clippings, nationality, buds, householder, jethro, zerby, redefine,
# Nearest to some: wendt, variant, harnessed, concerted, pilots, mantled, gdu, phonetic,
# Nearest to marriage: hooker, viewpoint, psychologists, beekeepers, morpheus, napoli, arrival, cleanly,
# Nearest to discovered: loos, burning, hydronium, hills, arctocephalus, webcomics, sisterhood, churn,
# Nearest to universe: organelles, disperse, beliefs, profumo, unreactive, wavelet, unwise, universitat,
# Nearest to orthodox: buddha, muslim, equinox, greeks, sinthasomphone, jews, pentecost, favor,
# Nearest to notes: cummins, decapitated, informative, antiaircraft, fertilization, parsing, rudin, bres,
# Nearest to centre: quixote, gallery, dona, dhahran, sandstone, installations, infielder, illinois,
# Nearest to powers: emerging, negotiate, dissolution, retain, succulent, capitalism, court, mikl,
# Nearest to units: robotic, makeup, standard, nonexistence, intuitively, udp, hindustan, protected,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2879 0.0311 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2848 0.0301 sec/batch
# 4627000
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3489 0.0146 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2656 0.0300 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2291 0.0302 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1933 0.0302 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2203 0.0302 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1925 0.0300 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2408 0.0297 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2014 0.0298 sec/batch
# Nearest to this: the, by, approaches, hypothetical, infinite, cardigan, sakae, pronouncing,
# Nearest to be: sturm, encodes, pps, religous, contention, abuser, should, falun,
# Nearest to four: two, zero, seven, six, one, three, five, weir,
# Nearest to were: archers, had, nyx, punic, saturnalia, bolshevik, was, rufinus,
# Nearest to his: vengeance, indecision, succeeded, apollodorus, surprised, hsls, deceit, tackled,
# Nearest to often: athabaskan, narrower, geologic, practicality, correlating, deformation, fond, primal,
# Nearest to people: literature, householder, nationality, clippings, zerby, redefine, buds, affiliation,
# Nearest to some: wendt, harnessed, concerted, variant, well, been, mantled, fasting,
# Nearest to marriage: hooker, viewpoint, napoli, livia, psychologists, morpheus, sees, beekeepers,
# Nearest to discovered: burning, loos, hydronium, sisterhood, hills, synthetic, arctocephalus, overactive,
# Nearest to universe: disperse, organelles, profumo, beliefs, unreactive, pyle, unwise, universitat,
# Nearest to orthodox: buddha, greeks, equinox, muslim, sinthasomphone, pentecost, jews, pagans,
# Nearest to notes: cummins, parsing, informative, bres, decapitated, rudin, antiaircraft, fertilization,
# Nearest to centre: quixote, sandstone, dona, gallery, dhahran, kush, installations, ferries,
# Nearest to powers: negotiate, emerging, dissolution, retain, courts, nijhoff, capitalism, expectation,
# Nearest to units: makeup, robotic, protected, hindustan, standard, tens, hydrographic, nonexistence,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2619 0.0311 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2256 0.0302 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2253 0.0301 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1413 0.0300 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1751 0.0298 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1614 0.0298 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1496 0.0300 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1890 0.0301 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1996 0.0302 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1914 0.0299 sec/batch
# Nearest to this: the, by, approaches, infinite, sakae, pronouncing, hypothetical, complacent,
# Nearest to be: sturm, religous, should, contention, encodes, abuser, kestrels, pps,
# Nearest to four: zero, two, seven, six, five, one, three, apologised,
# Nearest to were: archers, had, bolshevik, saturnalia, was, motivates, nyx, early,
# Nearest to his: vengeance, tackled, surprised, indecision, deceit, apollodorus, succeeded, repay,
# Nearest to often: athabaskan, narrower, practicality, geologic, correlating, fond, deformation, immature,
# Nearest to people: literature, nationality, householder, clippings, zerby, redefine, buds, vagrant,
# Nearest to some: harnessed, been, well, concerted, fasting, variant, mantled, activists,
# Nearest to marriage: livia, hooker, napoli, viewpoint, psychologists, morpheus, magnates, sees,
# Nearest to discovered: loos, synthetic, hydronium, burning, sisterhood, arctocephalus, inorganic, overactive,
# Nearest to universe: disperse, organelles, beliefs, profumo, unwise, pyle, semitism, unreactive,
# Nearest to orthodox: buddha, equinox, greeks, sinthasomphone, muslim, pentecost, conformity, jews,
# Nearest to notes: cummins, parsing, informative, rudin, largo, berserker, bres, decapitated,
# Nearest to centre: quixote, sandstone, dona, gallery, dhahran, kush, barge, installations,
# Nearest to powers: negotiate, emerging, dissolution, nijhoff, courts, retain, mikl, rebellion,
# Nearest to units: robotic, hindustan, makeup, standard, protected, tens, decrement, hydrographic,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1771 0.0310 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2275 0.0299 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1657 0.0298 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1566 0.0299 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1874 0.0299 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1702 0.0300 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1882 0.0300 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1572 0.0298 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1422 0.0298 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2300 0.0297 sec/batch
# Nearest to this: the, by, sakae, infinite, approaches, cardigan, hypothetical, ulmanis,
# Nearest to be: sturm, religous, encodes, kestrels, should, contention, pps, countably,
# Nearest to four: two, zero, seven, six, one, three, five, eight,
# Nearest to were: archers, had, bolshevik, nyx, motivates, emphasise, early, infringe,
# Nearest to his: indecision, deceit, succeeded, repay, apollodorus, surprised, vengeance, tackled,
# Nearest to often: athabaskan, practicality, deformation, narrower, geologic, correlating, embrace, donuts,
# Nearest to people: nationality, literature, householder, redefine, vagrant, clippings, zerby, births,
# Nearest to some: harnessed, well, concerted, wendt, been, variant, activists, mantled,
# Nearest to marriage: hooker, livia, napoli, psychologists, viewpoint, mashad, benson, magnates,
# Nearest to discovered: loos, synthetic, burning, hydronium, arctocephalus, sisterhood, inorganic, cosmological,
# Nearest to universe: disperse, organelles, profumo, pyle, unwise, unreactive, beliefs, awry,
# Nearest to orthodox: buddha, equinox, greeks, muslim, sinthasomphone, conformity, pentecost, favor,
# Nearest to notes: cummins, parsing, informative, rudin, berserker, bres, decapitated, largo,
# Nearest to centre: quixote, sandstone, gallery, dhahran, dona, installations, infielder, kush,
# Nearest to powers: negotiate, emerging, sentences, identity, dissolution, nijhoff, courts, mikl,
# Nearest to units: robotic, makeup, standard, hindustan, protected, tons, hydrographic, nonexistence,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2061 0.0311 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1577 0.0303 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1613 0.0301 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1743 0.0301 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1523 0.0300 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1393 0.0298 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1654 0.0299 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1121 0.0301 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2102 0.0302 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2220 0.0302 sec/batch
# Nearest to this: by, the, cardigan, sakae, ulmanis, infinite, follow, hypothetical,
# Nearest to be: sturm, pps, religous, encodes, should, contention, falun, abuser,
# Nearest to four: two, zero, seven, six, one, five, three, eight,
# Nearest to were: archers, had, bolshevik, was, rufinus, nyx, saturnalia, emphasise,
# Nearest to his: indecision, apollodorus, succeeded, repay, surprised, deceit, teresa, eleanor,
# Nearest to often: athabaskan, practicality, deformation, correlating, narrower, words, fond, donuts,
# Nearest to people: nationality, literature, householder, births, vagrant, redefine, neoplatonist, zerby,
# Nearest to some: wendt, variant, well, concerted, harnessed, rhineland, been, activists,
# Nearest to marriage: hooker, livia, psychologists, napoli, mashad, viewpoint, beekeepers, magnates,
# Nearest to discovered: loos, synthetic, burning, sisterhood, pham, arctocephalus, dame, hydronium,
# Nearest to universe: disperse, profumo, organelles, pyle, unwise, ahl, ding, beliefs,
# Nearest to orthodox: buddha, equinox, sinthasomphone, favor, muslim, conformity, pentecost, adjectival,
# Nearest to notes: cummins, parsing, berserker, informative, rudin, bres, decapitated, largo,
# Nearest to centre: quixote, sandstone, dona, dhahran, gallery, infielder, kush, installations,
# Nearest to powers: negotiate, emerging, identity, sentences, retain, nijhoff, dissolution, courts,
# Nearest to units: robotic, protected, makeup, hydrographic, standard, tons, tens, hindustan,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2221 0.0309 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1477 0.0298 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1523 0.0295 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1432 0.0299 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0609 0.0300 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1611 0.0301 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1384 0.0300 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1396 0.0300 sec/batch
# 4627000
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1631 0.0063 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1063 0.0297 sec/batch
# Nearest to this: the, by, sakae, aperture, cardigan, infinite, hypothetical, week,
# Nearest to be: encodes, sturm, denotation, should, pps, an, collimated, falun,
# Nearest to four: zero, two, six, seven, three, one, five, eight,
# Nearest to were: archers, had, rufinus, nyx, fricatives, homebrew, bolshevik, magnus,
# Nearest to his: indecision, repay, apollodorus, surprised, succeeded, deceit, vengeance, tackled,
# Nearest to often: athabaskan, deformation, correlating, practicality, narrower, words, outsourcing, fond,
# Nearest to people: nationality, householder, births, literature, vagrant, clippings, redefine, carnage,
# Nearest to some: variant, well, harnessed, concerted, been, mantled, gdu, fasting,
# Nearest to marriage: psychologists, hooker, napoli, livia, mashad, viewpoint, magnates, cowboys,
# Nearest to discovered: synthetic, loos, burning, pham, sisterhood, arctocephalus, hydronium, hills,
# Nearest to universe: profumo, disperse, organelles, pyle, awry, unwise, ding, big,
# Nearest to orthodox: buddha, equinox, sinthasomphone, muslim, conformity, adjectival, pentecost, favor,
# Nearest to notes: cummins, parsing, berserker, bres, rudin, tone, decapitated, informative,
# Nearest to centre: quixote, gallery, dhahran, dona, rooms, sandstone, infielder, myth,
# Nearest to powers: negotiate, identity, sentences, emerging, nijhoff, claimant, expectation, retain,
# Nearest to units: standard, robotic, makeup, hydrographic, protected, tons, tens, bromide,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0829 0.0312 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0742 0.0301 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0931 0.0300 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0321 0.0300 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0894 0.0301 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0521 0.0300 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0771 0.0297 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1051 0.0300 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1429 0.0298 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0418 0.0301 sec/batch
# Nearest to this: the, by, sakae, week, ulmanis, infinite, cardigan, aperture,
# Nearest to be: sturm, encodes, pps, to, denotation, religous, contention, afterthought,
# Nearest to four: two, zero, six, seven, three, one, five, eight,
# Nearest to were: archers, had, was, battalions, fricatives, early, bolshevik, nyx,
# Nearest to his: indecision, repay, apollodorus, succeeded, vengeance, surprised, deceit, teresa,
# Nearest to often: athabaskan, practicality, correlating, deformation, narrower, outsourcing, fond, words,
# Nearest to people: nationality, householder, births, literature, vagrant, redefine, carnage, clippings,
# Nearest to some: well, variant, been, concerted, harnessed, rhineland, activists, fasting,
# Nearest to marriage: livia, hooker, napoli, mashad, psychologists, viewpoint, magnates, adjudication,
# Nearest to discovered: synthetic, burning, sisterhood, loos, hydronium, inorganic, pham, cosmological,
# Nearest to universe: big, organelles, profumo, pyle, disperse, awry, unwise, predictions,
# Nearest to orthodox: buddha, pentecost, equinox, sinthasomphone, conformity, adjectival, atheism, armenian,
# Nearest to notes: cummins, parsing, bres, berserker, rudin, tone, decapitated, largo,
# Nearest to centre: gallery, quixote, sandstone, dhahran, rooms, dona, barge, myth,
# Nearest to powers: negotiate, sentences, claimant, identity, emerging, retain, expectation, nijhoff,
# Nearest to units: robotic, hydrographic, standard, tons, armed, makeup, protected, forces,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0271 0.0312 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0153 0.0300 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0277 0.0296 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0563 0.0298 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0890 0.0302 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0457 0.0304 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0412 0.0299 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1112 0.0300 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0239 0.0300 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0654 0.0295 sec/batch
# Nearest to this: the, infinite, by, sakae, accents, simpler, aperture, good,
# Nearest to be: should, sturm, encodes, denotation, an, to, religous, when,
# Nearest to four: two, zero, six, seven, three, one, five, eight,
# Nearest to were: archers, had, fricatives, early, battalions, emphasise, large, homebrew,
# Nearest to his: indecision, teresa, repay, apollodorus, surprised, vengeance, deceit, didn,
# Nearest to often: athabaskan, practicality, narrower, outsourcing, fond, deformation, immature, accent,
# Nearest to people: nationality, births, householder, literature, vagrant, redefine, makeup, carnage,
# Nearest to some: well, variant, been, harnessed, activists, concerted, rhineland, mantled,
# Nearest to marriage: napoli, hooker, livia, mashad, psychologists, hamdi, naturalisation, viewpoint,
# Nearest to discovered: synthetic, hydronium, pham, jupiter, cosmological, burning, sisterhood, loos,
# Nearest to universe: big, profumo, disperse, pyle, unwise, predictions, ahl, organelles,
# Nearest to orthodox: buddha, equinox, pentecost, sinthasomphone, favor, conformity, armenian, adjectival,
# Nearest to notes: cummins, parsing, berserker, rudin, bres, informative, tone, decapitated,
# Nearest to centre: gallery, quixote, sandstone, dhahran, rooms, barge, locations, ferries,
# Nearest to powers: negotiate, sentences, retain, emerging, claimant, expectation, identity, nijhoff,
# Nearest to units: makeup, robotic, hydrographic, standard, tons, bromide, armed, tens,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0411 0.0311 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0772 0.0302 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0588 0.0302 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0769 0.0300 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0822 0.0302 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0539 0.0301 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0745 0.0300 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0719 0.0300 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0902 0.0301 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0763 0.0301 sec/batch
# Nearest to this: the, by, infinite, ulmanis, constitutes, accents, week, sakae,
# Nearest to be: sturm, should, denotation, religous, abuser, encodes, pps, afterthought,
# Nearest to four: two, zero, seven, three, six, one, five, eight,
# Nearest to were: had, archers, magnus, was, early, bolshevik, battalions, bessarabia,
# Nearest to his: succeeded, indecision, apollodorus, bestowed, repay, teresa, deceit, vengeance,
# Nearest to often: athabaskan, practicality, donuts, outsourcing, fond, narrower, deformation, embrace,
# Nearest to people: nationality, births, householder, literature, vagrant, carnage, redefine, relatedness,
# Nearest to some: well, variant, rhineland, harnessed, activists, been, extents, concerted,
# Nearest to marriage: napoli, hooker, livia, psychologists, naturalisation, mashad, hamdi, magnates,
# Nearest to discovered: pham, synthetic, jupiter, cosmological, loos, sisterhood, arctocephalus, agate,
# Nearest to universe: big, profumo, pyle, disperse, ahl, organelles, unwise, predictions,
# Nearest to orthodox: buddha, equinox, sinthasomphone, conformity, pentecost, adjectival, favor, chalcedonians,
# Nearest to notes: parsing, cummins, bres, berserker, rudin, informative, tone, decapitated,
# Nearest to centre: gallery, quixote, dhahran, rooms, sandstone, locations, myth, dona,
# Nearest to powers: negotiate, claimant, sentences, retain, emerging, expectation, nijhoff, fortress,
# Nearest to units: makeup, standard, robotic, hydrographic, tons, reginald, protected, armed,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0620 0.0310 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9904 0.0301 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0336 0.0298 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0524 0.0299 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0668 0.0302 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1080 0.0300 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1168 0.0299 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0462 0.0299 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0079 0.0297 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0678 0.0298 sec/batch
# Nearest to this: the, by, week, infinite, constitutes, sakae, good, accents,
# Nearest to be: sturm, should, therefore, an, encodes, denotation, uppercase, negotiable,
# Nearest to four: two, zero, seven, six, one, five, three, eight,
# Nearest to were: had, archers, fricatives, large, rufinus, magnus, emphasise, iranians,
# Nearest to his: indecision, repay, succeeded, teresa, apollodorus, him, bestowed, career,
# Nearest to often: athabaskan, practicality, words, outsourcing, narrower, donuts, hardly, traditionally,
# Nearest to people: births, nationality, vagrant, relatedness, householder, carnage, khmer, literature,
# Nearest to some: well, variant, harnessed, activists, rhineland, vermouth, geb, mantled,
# Nearest to marriage: napoli, hooker, livia, psychologists, naturalisation, hamdi, mashad, magnates,
# Nearest to discovered: pham, loos, jupiter, sisterhood, arctocephalus, synthetic, agate, envisioned,
# Nearest to universe: profumo, big, pyle, disperse, unwise, ding, organelles, ahl,
# Nearest to orthodox: buddha, equinox, sinthasomphone, favor, forward, conformity, adjectival, pentecost,
# Nearest to notes: cummins, parsing, bres, rudin, berserker, tone, decapitated, informative,
# Nearest to centre: gallery, rooms, dhahran, quixote, sandstone, locations, dona, installations,
# Nearest to powers: negotiate, expectation, claimant, breaks, sentences, emerging, flak, retain,
# Nearest to units: makeup, hydrographic, standard, tons, robotic, monic, customary, armed,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9975 0.0308 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0306 0.0302 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0394 0.0299 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0267 0.0299 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0683 0.0301 sec/batch
# 4627000
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0351 0.0283 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0397 0.0299 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9966 0.0300 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9797 0.0302 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9654 0.0302 sec/batch
# Nearest to this: the, week, by, sakae, infinite, good, constitutes, simpler,
# Nearest to be: sturm, pps, should, negotiable, an, uppercase, denotation, encodes,
# Nearest to four: two, zero, one, six, three, seven, five, eight,
# Nearest to were: had, archers, large, fricatives, battalions, emphasise, rufinus, nyx,
# Nearest to his: indecision, succeeded, teresa, repay, bestowed, him, poor, career,
# Nearest to often: athabaskan, practicality, outsourcing, fond, behaviors, narrower, oils, men,
# Nearest to people: nationality, births, vagrant, householder, relatedness, redefine, utero, literature,
# Nearest to some: well, variant, rhineland, harnessed, been, less, activists, has,
# Nearest to marriage: napoli, livia, mashad, hooker, hamdi, naturalisation, psychologists, abductions,
# Nearest to discovered: pham, jupiter, loos, arctocephalus, synthetic, after, sisterhood, envisioned,
# Nearest to universe: profumo, big, pyle, disperse, unwise, awry, ahl, memorialized,
# Nearest to orthodox: buddha, equinox, sinthasomphone, bulgarians, forward, pentecost, chalcedonians, favor,
# Nearest to notes: parsing, cummins, bres, rudin, berserker, tone, decapitated, octave,
# Nearest to centre: quixote, rooms, sandstone, dhahran, gallery, locations, myth, gorges,
# Nearest to powers: negotiate, claimant, expectation, fortress, sentences, flak, breaks, nijhoff,
# Nearest to units: hydrographic, makeup, robotic, armed, tons, bromide, standard, decrement,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9988 0.0311 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9312 0.0301 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0263 0.0299 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0052 0.0298 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0524 0.0298 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0017 0.0298 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9269 0.0300 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9604 0.0300 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9408 0.0300 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9619 0.0300 sec/batch
# Nearest to this: the, infinite, sakae, week, constitutes, accents, good, by,
# Nearest to be: should, sturm, denotation, uppercase, pps, collimated, to, an,
# Nearest to four: two, zero, one, three, six, seven, five, eight,
# Nearest to were: had, archers, large, battalions, fricatives, early, homebrew, magnus,
# Nearest to his: indecision, teresa, career, repay, him, guile, tackled, poor,
# Nearest to often: practicality, athabaskan, outsourcing, oils, behaviors, embrace, narrower, men,
# Nearest to people: nationality, births, vagrant, householder, relatedness, makeup, literature, khmer,
# Nearest to some: well, variant, rhineland, been, less, symplectic, differences, extents,
# Nearest to marriage: napoli, livia, mashad, naturalisation, hooker, hamdi, psychologists, adjudication,
# Nearest to discovered: jupiter, pham, synthetic, arctocephalus, cosmological, envisioned, agate, martin,
# Nearest to universe: big, profumo, disperse, pyle, fermi, awry, predictions, unwise,
# Nearest to orthodox: buddha, sinthasomphone, equinox, bulgarians, pentecost, forward, chalcedonians, adjectival,
# Nearest to notes: cummins, parsing, bres, berserker, rudin, tone, octave, accredited,
# Nearest to centre: quixote, rooms, sandstone, gallery, dhahran, locations, dona, gorges,
# Nearest to powers: negotiate, claimant, flak, breaks, skat, coffey, expectation, nijhoff,
# Nearest to units: hydrographic, makeup, tons, robotic, armed, decrement, standard, danner,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9723 0.0308 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9956 0.0301 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9677 0.0301 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9832 0.0300 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0444 0.0301 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9464 0.0301 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0303 0.0300 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9988 0.0297 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9871 0.0301 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9679 0.0300 sec/batch
# Nearest to this: the, week, accents, ulmanis, infinite, sakae, good, constitutes,
# Nearest to be: sturm, to, should, uppercase, an, denotation, contention, beli,
# Nearest to four: two, zero, three, one, six, seven, five, eight,
# Nearest to were: had, archers, magnus, homebrew, large, early, emphasise, fricatives,
# Nearest to his: repay, indecision, career, him, teresa, guile, succeeded, he,
# Nearest to often: practicality, athabaskan, outsourcing, oils, narrower, cost, men, hardly,
# Nearest to people: births, nationality, vagrant, householder, redefine, makeup, ibero, relatedness,
# Nearest to some: well, rhineland, variant, been, differences, symplectic, antithetical, dilemmas,
# Nearest to marriage: napoli, livia, hooker, mashad, hamdi, naturalisation, magnates, benson,
# Nearest to discovered: pham, jupiter, arctocephalus, martin, after, synthetic, cosmological, loos,
# Nearest to universe: big, profumo, pyle, disperse, dark, predictions, memorialized, ahl,
# Nearest to orthodox: buddha, equinox, sinthasomphone, bulgarians, favor, forward, chalcedonians, conformity,
# Nearest to notes: cummins, parsing, bres, rudin, berserker, informative, accredited, largo,
# Nearest to centre: rooms, quixote, gallery, sandstone, dhahran, locations, dona, barge,
# Nearest to powers: negotiate, expectation, claimant, declare, skat, flak, breaks, nijhoff,
# Nearest to units: makeup, hydrographic, decrement, standard, robotic, monic, customary, bromide,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0102 0.0309 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9781 0.0301 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9761 0.0299 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0214 0.0299 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0201 0.0300 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0128 0.0299 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0109 0.0301 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9682 0.0300 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9820 0.0300 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0040 0.0301 sec/batch
# Nearest to this: week, the, ulmanis, infinite, sakae, constitutes, by, follow,
# Nearest to be: an, should, to, beli, upsetting, sturm, uppercase, negotiable,
# Nearest to four: two, zero, three, one, seven, six, five, eight,
# Nearest to were: had, large, archers, evaded, still, battalions, iranians, magnus,
# Nearest to his: teresa, repay, indecision, career, him, succeeded, he, guile,
# Nearest to often: practicality, outsourcing, athabaskan, men, behaviors, hardly, donuts, fond,
# Nearest to people: births, nationality, vagrant, householder, redefine, current, ibero, relatedness,
# Nearest to some: well, rhineland, variant, has, use, been, differences, dilemmas,
# Nearest to marriage: napoli, livia, hamdi, naturalisation, mashad, hooker, beekeepers, magnates,
# Nearest to discovered: pham, arctocephalus, after, martin, jupiter, cosmological, sisterhood, gaspard,
# Nearest to universe: big, profumo, disperse, pyle, fermi, ahl, dark, organelles,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8136 0.0304 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8330 0.0302 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8805 0.0297 sec/batch
# Nearest to this: the, that, and, an, a, is, only, as,
# Nearest to be: to, it, an, that, other, only, when, all,
# Nearest to four: two, one, three, zero, five, six, eight, seven,
# Nearest to were: had, large, homebrew, still, well, been, those, was,
# Nearest to his: he, him, career, teresa, was, madhava, poor, ladies,
# Nearest to often: or, usually, sometimes, men, hardly, practicality, outsourcing, these,
# Nearest to people: births, nationality, vagrant, living, deaths, genuinely, neurobiological, caucasoid,
# Nearest to some: well, other, not, many, have, and, been, are,
# Nearest to marriage: marry, pupal, fornication, naturalisation, ry, marriages, livia, hamdi,
# Nearest to discovered: discovery, cosimo, sunyaev, discoverer, arctocephalus, rajasthan, creutzfeldt, agate,
# Nearest to universe: big, profumo, albans, ahl, fermi, inflation, adventurers, unwise,
# Nearest to orthodox: bulgarians, chalcedonians, slovaks, unconditional, cossacks, favor, forward, consolations,
# Nearest to notes: bres, homepage, octave, cummins, previews, berserker, ernie, parsing,
# Nearest to centre: rooms, dona, city, specifying, ferries, disused, myth, scrape,
# Nearest to powers: skat, maslow, coffey, wffs, brinton, creator, polyhedron, dual,
# Nearest to units: makeup, hispanic, unit, hydrographic, si, islander, weights, residing,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8109 0.0310 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8700 0.0300 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8411 0.0302 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8391 0.0301 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8708 0.0300 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8898 0.0298 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8763 0.0298 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8481 0.0301 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8931 0.0301 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8660 0.0301 sec/batch
# Nearest to this: the, an, in, that, only, somewhere, is, by,
# Nearest to be: to, it, that, an, other, only, all, of,
# Nearest to four: two, one, three, five, zero, eight, six, seven,
# Nearest to were: had, still, large, been, was, well, in, those,
# Nearest to his: he, him, teresa, career, was, succeeded, eldest, madhava,
# Nearest to often: or, sometimes, usually, hardly, embody, outsourcing, men, extremity,
# Nearest to people: births, nationality, living, vagrant, deaths, caucasoid, neurobiological, ancestries,
# Nearest to some: well, other, many, are, have, not, use, and,
# Nearest to marriage: marry, pupal, naturalisation, ry, fornication, marriages, napoli, holst,
# Nearest to discovered: discovery, cosimo, sunyaev, after, creutzfeldt, discoverer, rajasthan, overwhelmingly,
# Nearest to universe: big, albans, profumo, ahl, fermi, adventurers, inflation, cosmological,
# Nearest to orthodox: chalcedonians, bulgarians, unconditional, cossacks, favor, slovaks, billings, forward,
# Nearest to notes: bres, homepage, previews, cummins, informative, octave, discussed, parsing,
# Nearest to centre: rooms, myth, specifying, ferries, city, dona, dhahran, centres,
# Nearest to powers: skat, maslow, coffey, creator, vested, brinton, wffs, enacted,
# Nearest to units: makeup, hispanic, unit, islander, hydrographic, si, kilograms, watt,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.9019 0.0313 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8650 0.0301 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8310 0.0297 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8254 0.0296 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8841 0.0305 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8344 0.0303 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9526 0.0303 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8731 0.0302 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8971 0.0302 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8018 0.0299 sec/batch
# Nearest to this: the, country, epimorphism, an, somewhere, only, ulmanis, a,
# Nearest to be: an, that, to, it, other, also, only, of,
# Nearest to four: two, one, three, zero, five, eight, six, seven,
# Nearest to were: had, large, still, those, well, was, been, included,
# Nearest to his: he, him, was, career, teresa, ladies, kertzer, collaborating,
# Nearest to often: sometimes, or, usually, hardly, embody, these, men, practicality,
# Nearest to people: births, living, vagrant, nationality, politicians, deaths, ancestries, genuinely,
# Nearest to some: well, many, are, other, not, use, have, and,
# Nearest to marriage: marry, naturalisation, pupal, ry, livia, fornication, marriages, holst,
# Nearest to discovered: discovery, cosimo, sunyaev, discoverer, after, overwhelmingly, rajasthan, creutzfeldt,
# Nearest to universe: big, profumo, albans, ahl, adventurers, fermi, inflation, boosters,
# Nearest to orthodox: bulgarians, chalcedonians, slovaks, unconditional, forward, favor, cossacks, numbered,
# Nearest to notes: bres, homepage, octave, cummins, previews, unconditional, discussed, call,
# Nearest to centre: myth, rooms, specifying, busway, dhahran, dona, tres, ferries,
# Nearest to powers: skat, coffey, maslow, creator, wffs, defeat, dual, counterattack,
# Nearest to units: makeup, hispanic, unit, islander, si, hydrographic, weights, watt,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7971 0.0307 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8521 0.0302 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7825 0.0301 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8581 0.0301 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8385 0.0301 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8578 0.0299 sec/batch
# 4627000
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9186 0.0176 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8293 0.0300 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8284 0.0302 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8399 0.0301 sec/batch
# Nearest to this: the, somewhere, epimorphism, an, it, and, only, a,
# Nearest to be: it, an, that, other, to, also, only, as,
# Nearest to four: two, one, three, five, six, eight, zero, seven,
# Nearest to were: had, still, was, large, those, well, pulmonic, few,
# Nearest to his: he, was, him, career, teresa, succeeded, eldest, bohemund,
# Nearest to often: sometimes, or, usually, hardly, men, outsourcing, embody, construe,
# Nearest to people: births, living, nationality, vagrant, politicians, neurobiological, deaths, ancestries,
# Nearest to some: other, many, well, not, have, are, use, and,
# Nearest to marriage: marry, pupal, marriages, fornication, naturalisation, ry, her, livia,
# Nearest to discovered: discovery, cosimo, sunyaev, discoverer, rajasthan, lemy, relatives, overwhelmingly,
# Nearest to universe: big, albans, profumo, ahl, universes, boosters, fermi, adventurers,
# Nearest to orthodox: bulgarians, chalcedonians, slovaks, favor, billings, cossacks, nadal, numbered,
# Nearest to notes: bres, homepage, octave, cummins, ernie, discussed, unconditional, previews,
# Nearest to centre: rooms, myth, ferries, specifying, busway, tres, undocked, centres,
# Nearest to powers: maslow, coffey, skat, creator, wffs, magical, vested, brinton,
# Nearest to units: makeup, unit, hispanic, si, weights, islander, customary, conversion,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8288 0.0311 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8070 0.0301 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8308 0.0300 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7995 0.0300 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8678 0.0301 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8247 0.0300 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8789 0.0301 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7460 0.0301 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8148 0.0301 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7862 0.0297 sec/batch
# Nearest to this: the, an, a, only, is, and, country, in,
# Nearest to be: it, to, that, an, other, only, also, a,
# Nearest to four: two, one, three, zero, five, eight, six, seven,
# Nearest to were: had, still, was, well, those, large, been, pardey,
# Nearest to his: he, him, career, teresa, guile, bohemund, theoria, madhava,
# Nearest to often: or, sometimes, usually, hardly, embody, outsourcing, partials, with,
# Nearest to people: births, living, vagrant, deaths, nationality, ancestries, neurobiological, politicians,
# Nearest to some: well, many, other, are, have, and, not, been,
# Nearest to marriage: marry, pupal, ry, naturalisation, fornication, marriages, livia, gender,
# Nearest to discovered: discovery, cosimo, sunyaev, discoverer, overwhelmingly, invented, rajasthan, agate,
# Nearest to universe: big, albans, cosmological, profumo, inflation, ahl, universes, fermi,
# Nearest to orthodox: bulgarians, chalcedonians, favor, slovaks, concerned, cossacks, billings, unconditional,
# Nearest to notes: homepage, bres, cummins, octave, discussed, unconditional, ernie, previews,
# Nearest to centre: rooms, myth, ferries, glacier, tres, dona, gorges, centres,
# Nearest to powers: skat, maslow, coffey, creator, wffs, supp, vested, dual,
# Nearest to units: makeup, unit, si, hispanic, conversion, islander, weights, residing,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7450 0.0307 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8203 0.0301 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8529 0.0299 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7998 0.0300 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7995 0.0299 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8826 0.0302 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8605 0.0300 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8415 0.0299 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8432 0.0303 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8335 0.0298 sec/batch
# Nearest to this: the, is, a, and, an, in, of, only,
# Nearest to be: it, to, an, that, other, all, only, a,
# Nearest to four: two, three, one, zero, six, eight, five, seven,
# Nearest to were: had, still, was, well, those, pardey, few, included,
# Nearest to his: he, him, career, teresa, was, father, guile, bohemund,
# Nearest to often: or, usually, hardly, sometimes, men, embody, oils, these,
# Nearest to people: births, living, vagrant, nationality, deaths, ancestries, politicians, neurobiological,
# Nearest to some: many, well, and, other, are, not, have, been,
# Nearest to marriage: marry, pupal, ry, naturalisation, fornication, marriages, livia, her,
# Nearest to discovered: discovery, cosimo, discoverer, sunyaev, overwhelmingly, after, discoveries, telescopic,
# Nearest to universe: big, albans, cosmological, profumo, ahl, fermi, inflation, universes,
# Nearest to orthodox: bulgarians, chalcedonians, favor, slovaks, cossacks, concerned, allegedly, incarnation,
# Nearest to notes: bres, homepage, zei, previews, cummins, ernie, discussed, unconditional,
# Nearest to centre: rooms, myth, specifying, centres, tres, ferries, cholesteric, patron,
# Nearest to powers: skat, maslow, creator, wffs, vested, coffey, dual, fermilab,
# Nearest to units: makeup, hispanic, unit, si, conversion, residing, islander, weights,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8661 0.0312 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8447 0.0300 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8107 0.0300 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8402 0.0298 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8689 0.0300 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8633 0.0304 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8201 0.0300 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8611 0.0303 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8042 0.0302 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8232 0.0299 sec/batch
# Nearest to this: the, an, a, that, and, it, in, is,
# Nearest to be: to, an, it, that, other, of, a, also,
# Nearest to four: two, three, one, zero, five, six, eight, seven,
# Nearest to were: had, still, was, large, well, those, pardey, been,
# Nearest to his: he, him, career, teresa, was, son, madhava, eldest,
# Nearest to often: or, sometimes, usually, hardly, use, embody, many, men,
# Nearest to people: births, living, nationality, vagrant, deaths, neurobiological, ancestries, autodidacts,
# Nearest to some: many, well, are, and, have, other, not, to,
# Nearest to marriage: marry, pupal, marriages, fornication, her, livia, ry, naturalisation,
# Nearest to discovered: discovery, cosimo, discoverer, sunyaev, overwhelmingly, after, hypothesis, rajasthan,
# Nearest to universe: big, ahl, albans, profumo, adventurers, cosmological, universes, fermi,
# Nearest to orthodox: bulgarians, chalcedonians, favor, slovaks, cossacks, allegedly, icons, negev,
# Nearest to notes: homepage, bres, octave, cummins, discussed, zei, unconditional, call,
# Nearest to centre: myth, specifying, centres, tres, patron, rooms, trading, installations,
# Nearest to powers: maslow, skat, creator, wffs, magical, coffey, petsamo, vested,
# Nearest to units: makeup, hispanic, residing, islander, unit, si, customary, weights,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8716 0.0308 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8294 0.0302 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9385 0.0302 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9109 0.0302 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8761 0.0300 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8244 0.0302 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7852 0.0298 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8589 0.0301 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7437 0.0302 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8492 0.0301 sec/batch
# Nearest to this: is, the, a, an, only, common, and, as,
# Nearest to be: an, that, it, other, to, a, also, is,
# Nearest to four: two, one, three, zero, five, six, eight, seven,
# Nearest to were: had, still, was, those, well, few, pulmonic, large,
# Nearest to his: he, him, career, was, father, madhava, guile, kertzer,
# Nearest to often: or, usually, sometimes, hardly, many, these, use, embody,
# Nearest to people: births, living, vagrant, nationality, deaths, politicians, ancestries, autodidacts,
# Nearest to some: many, well, are, have, other, and, not, use,
# Nearest to marriage: marry, pupal, her, marriages, livia, naturalisation, fornication, ry,
# Nearest to discovered: discovery, cosimo, discoverer, sunyaev, overwhelmingly, rajasthan, after, arctocephalus,
# Nearest to universe: big, albans, profumo, ahl, adventurers, boosters, cosmological, universes,
# Nearest to orthodox: bulgarians, chalcedonians, slovaks, favor, concerned, cossacks, numbered, negev,
# Nearest to notes: homepage, discussed, bres, octave, unconditional, cummins, call, zei,
# Nearest to centre: myth, rooms, tres, specifying, patron, trading, centres, undocked,
# Nearest to powers: maslow, creator, skat, coffey, petsamo, magical, villainous, divine,
# Nearest to units: makeup, hispanic, unit, islander, si, weights, residing, customary,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8255 0.0312 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8189 0.0302 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE#https://blog.csdn.net/lpsl1882/article/details/58741475 KL convergence->KL散度

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
